# %% [markdown]
# # Ingeniería de Datos con Python

# %% [markdown]
# ## Introducción

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
print('segunda linea')
# Out:
# segunda linea

# %% [markdown]
# ## Tipos de datos

# %% [markdown]
# ### Primitivos

# %%
from datetime import datetime

integer_type = 42
float_type = 3.14159
bool_type = False
hex_type = 0xff
oct_type = 0o23
today = datetime.now()
str_type = 'David'

# %% [markdown]
# ### No estructurados

# %% [markdown]
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren't special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you're Dutch.
#
# Now is better than never.
#
# Although never is often better than *right* now.
#
# If the implementation is hard to explain, it's a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Solicitudes a la web

# %%
import requests

response = requests.get('https://www.platzi.com')

print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html lang="es_ES" data-cast-api-enabled="true"><head><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no" /><title>Platzi: Cursos online profesionales de tecnología</title><link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" /><link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png"><link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" /><meta name="description" content="Aprende desde cero a crear el futuro de la web. Cursos de Desarrollo, Diseño, Marketing, y Negocios."><meta name="theme-color" content="#15210B"/><!-- og tags Facebook --><meta property="fb:app_id" content="263680607075199" /><meta property="fb:admins" content="1030603473" /><meta property="og:description" content="Aprende desde cero a crear el futuro de la web. Cursos de programación, diseño, marketing, web, frontend, backend, móvil, UX, usabilidad. Con clases en vivo, diploma de certificación y maestros de la industria." /><meta property="og:title" content="Platzi: Cursos online profesionales de tecnología" /><meta property="og:type" content="website" /><meta property="og:url" content="https://platzi.com/"/><meta property="og:image" content="https://static.platzi.com/static/website/v2/images/social/social.423d47d2f6d6.jpg" /><meta property="og:site_name" content="platzi.com" /><!-- og tags Google+ --><meta itemprop="description" content="Aprende desde cero a crear el futuro de la web. Cursos de programación, diseño, marketing, web, frontend, backend, móvil, UX, usabilidad. Con clases en vivo, diploma de certificación y maestros de la industria." /><!-- Twitter Cards --><meta property="twitter:account_id" content="4503599630205252" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:site" content="@Platzi" /><meta name="twitter:title" content="Platzi: Cursos online profesionales de tecnología" /><meta name="twitter:description" content="Aprende desde cero a crear el futuro de la web. Cursos de programación, diseño, marketing, web, frontend, backend, móvil, UX, usabilidad. Con clases en vivo, diploma de certificación y maestros de la industria." /><meta name="twitter:creator" content="@Platzi" /><meta name="twitter:image:src" content="https://static.platzi.com/static/website/v2/images/social/social.423d47d2f6d6.jpg" /><meta name="twitter:domain" content="platzi.com" /><!-- SEO --><link rel="canonical" href="https://platzi.com/" /><!-- hreflang --><link rel="alternate" href="https://courses.platzi.com/" hreflang="en" /><link rel="alternate" href="https://platzi.com/" hreflang="es" /><!-- hreflang --><link rel="manifest" href="/onesignal.json" /><style type="text/css" defer async>
#   .onesignal-popover-dialog {
#     pointer-events: none !important;
#   }
#   .onesignal-popover-dialog > #normal-popover {
#     pointer-events: auto !important;
#   }
# </style><script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async></script><script type="text/javascript" defer async>
#   var OneSignal = window.OneSignal || [];
#    OneSignal.push(function() {
#      OneSignal.init({
#        appId: "8adc9051-61fc-438e-b19a-739a6bf780e5",
#      });
#    });
#  </script><script></script><!-- Analytics and FB Pixel Code --><script defer async>
#             (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#             window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#
#
#
#                 // Create Trackers
#                 ga('create', 'UA-76863-18', 'auto', 'platziPublicES');
#                 ga('create', 'UA-76863-27', 'auto', 'platziFull');
#
#
#                 // Require Plugins for platziPublicES
#                 ga('platziPublicES.require', 'ecommerce');
#                 ga('platziPublicES.require', 'outboundLinkTracker');
#                 ga('platziPublicES.require', 'socialWidgetTracker');
#
#                 // Require Plugins for platziFull
#                 ga('platziFull.require', 'ecommerce');
#                 ga('platziFull.require', 'outboundLinkTracker');
#                 ga('platziFull.require', 'socialWidgetTracker');
#
#
#                 // If userId, update userId
#
#
#                 //Send Pageview
#                 ga('platziPublicES.send', 'pageview');
#                 ga('platziFull.send', 'pageview');
#
#                 ga('platziPublicES.set', 'dimension2', 'anonymous');
#                 ga('platziFull.set', 'dimension2', 'anonymous');
#
#
#
#         </script><!-- Autotrack plugin for Google Analytics --><script async src="https://cdnjs.cloudflare.com/ajax/libs/autotrack/2.4.1/autotrack.js" defer async></script><!-- Facebook Pixel Code --><script defer async>
#                 !function(f,b,e,v,n,t,s)
#                 {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                     n.queue=[];t=b.createElement(e);t.async=!0;
#                     t.src=v;s=b.getElementsByTagName(e)[0];
#                     s.parentNode.insertBefore(t,s)}(window, document,'script',
#                     'https://connect.facebook.net/en_US/fbevents.js');
#                 fbq('init', '1545967215651797');
#                 fbq('track', 'PageView');
#             </script><noscript><img height="1" width="1" style="display:none"
#                            src="https://www.facebook.com/tr?id=1545967215651797&ev=PageView&noscript=1"
#             /></noscript><!-- End Facebook Pixel Code --><script type="text/javascript">
#             _linkedin_data_partner_id = "274754";
#             </script><script type="text/javascript" defer async>
#             (function(){var s = document.getElementsByTagName("script")[0];
#             var b = document.createElement("script");
#             b.type = "text/javascript";b.async = true;
#             b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#             s.parentNode.insertBefore(b, s);})();
#             </script><noscript><img height="1" width="1" style="display:none;" alt="" src="https://dc.ads.linkedin.com/collect/?pid=274754&fmt=gif" /></noscript><!-- End Analytics and FB Pixel Code --><!-- Twitter universal website tag code --><script defer async>
#             !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
#             },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
#                 a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
#             // Insert Twitter Pixel ID and Standard Event data below
#             twq('init','nyfpx');
#             twq('track','PageView');
#         </script><!-- End Twitter universal website tag code --><!-- Hotjar Tracking Code for www.platzi.com --><script defer async>
#           (function(h,o,t,j,a,r){
#               h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#               h._hjSettings={hjid:430680,hjsv:5};
#               a=o.getElementsByTagName('head')[0];
#               r=o.createElement('script');r.async=1;
#               r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#               a.appendChild(r);
#           })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#         </script><!-- Begin Inspectlet JS Code --><script type="text/javascript" id="inspectletjs" defer async>
#             (function() {
#             var insp_ab_loader = false; // set this boolean to false to disable the A/B testing loader
#             window.__insp = window.__insp || [];
#             __insp.push(['wid', 1550190489]);
#             var ldinsp = function(){
#             if(typeof window.__inspld != "undefined") return; window.__inspld = 1; var insp = document.createElement('script'); insp.type = 'text/javascript'; insp.async = true; insp.id = "inspsync"; insp.src = ('https:' == document.location.protocol ? 'https' : 'http') + '://cdn.inspectlet.com/inspectlet.js?wid=1550190489&r=' + Math.floor(new Date().getTime()/3600000); var x = document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(insp, x);if(typeof insp_ab_loader != "undefined" && insp_ab_loader){ var adlt = function(){ var e = document.getElementById('insp_abl'); if(e){ e.parentNode.removeChild(e); __insp.push(['ab_timeout']); }}; var adlc = "body{ visibility: hidden !important; }"; var adln = typeof insp_ab_loader_t != "undefined" ? insp_ab_loader_t : 1200; insp.onerror = adlt; var abti = setTimeout(adlt, adln); window.__insp_abt = abti; var abl = document.createElement('style'); abl.id = "insp_abl"; abl.type = "text/css"; if(abl.styleSheet) abl.styleSheet.cssText = adlc; else abl.appendChild(document.createTextNode(adlc)); document.head.appendChild(abl); } };
#             setTimeout(ldinsp, 0);
#             })();
#         </script><!-- End Inspectlet JS Code --><!-- add more stylesheets --><link type="text/css" href="https://static.platzi.com/static/css/core/header-v2.4dab4b08119b4bd02d27.css.gz" rel="stylesheet" /><link type="text/css" href="https://static.platzi.com/static/css/d/contact-modal.071242ee7ad31ffa1c09.css.gz" rel="stylesheet" /><link type="text/css" href="https://static.platzi.com/static/css/d/contact-modal.071242ee7ad31ffa1c09.css.gz" rel="stylesheet" /><link type="text/css" href="https://static.platzi.com/static/css/core/home-v3.4dab4b08119b4bd02d27.css.gz" rel="stylesheet" /><!-- add more metatags --><script type="text/javascript">
#             window.header = {"live": {"active": false, "time": "", "url": ""}, "menuItems": [{"name": "Cursos", "url": "/cursos/"}, {"name": "Cont\u00e1ctanos", "url": "", "type": "contact"}, {"name": "Blog", "url": "/blog/"}, {"name": "Agenda", "url": "/agenda/"}, {"name": "Foro", "url": "/foro/"}], "loggedMenu": [{"name": "Empleos", "icon": "icon-suitecase_B", "url": "/empleos/"}, {"name": "Mensajes Directos", "type": "direct_messages", "icon": "icon-cloud", "url": "/direct-messages/"}, {"name": "Obt\u00e9n 1 mes gratis", "icon": "icon-gift_A", "type": "referal", "url": "/mi-suscripcion/referidos/"}, {"name": "Mi Suscripci\u00f3n", "icon": "icon-platzi", "type": "my_subscription", "url": "/mi-suscripcion/"}], "avatar": "", "points": "", "name": "", "username": "", "profileUrl": "", "userId": "", "plan": "", "subscriptionTime": "", "enableSearch": true, "enableSubscription": true, "isLogged": false, "messages": {"continue_watching": "Continua viendo", "all_courses": "Ver todos mis cursos", "username": "\u00a1Hola! {user_name}", "subscriptionTime": "Tienes {subscription_time} d\u00edas de tu Plan", "view_profile": "Ver mi Perfil", "logout": "Cerrar sesi\u00f3n", "login": "Iniciar sesi\u00f3n", "live_in": "Live en ", "live": "live", "menu": "Men\u00fa", "view_plans": "Quiero saber m\u00e1s", "courses": "Cursos", "more_results": "M\u00e1s resultados", "careers": "Carreras", "no_results": "No tenemos resultados destacados", "avanced_search": "Presiona ENTER para una busqueda avanzada", "init_plan": "Iniciar mi plan", "init_plan2": "Planes", "switch_language": "Do you want to switch to Platzi in English?", "switch_english": "Yes, switch to English", "user_login": "Inicia sesi\u00f3n o crea tu cuenta", "nextPage": "Siguiente", "searchPlaceholder": "Buscar en Platzi", "login_live_text": "Participa en sesiones en vivo y foros de Platzi", "login_courses_text": "Accede a m\u00e1s de 120 cursos", "login_opportunities": "Accede a mejores oportunidades laborales", "mark_as_read": "Marcar todas como le\u00eddas", "title": "Tus notificaciones", "hide": "Ocultar", "hide_description": "Ocultar esta notificaci\u00f3n del historial", "undo": "Deshacer", "notification_hidden": "Se ocult\u00f3 la notificati\u00f3n.", "notification_empty_title": "\u00a1A\u00fan no tienes notificaciones!", "notification_emtpy_subtitle": "Participa, comparte y discute para empezar a recibir notificaciones", "see_all": "Ver todas", "notifications_disabled_title": "\u00a1Tus notificaciones est\u00e1n desactivadas!", "notification_not_available_title": "\u00a1Lo sentimos!", "notifications_not_available_subtitle": "El contenido al que intentas acceder no se encuentra disponible.", "notifications_disabled_subtitle": "Para recibir nuevamente tus notificaciones debes activarlas en <span class=\"icon-cog\"></span>"}, "locale": "es", "isHispanic": true, "options": [{"title": "Preguntas frecuentes", "url": "/faq/"}, {"title": "Cont\u00e1ctanos", "url": "/contacto/"}, {"title": "Prensa", "url": "/prensa/"}, {"title": "Conferencias", "url": "/conf/todas/"}, {"title": "T\u00e9rminos y Condiciones", "url": "/tos/"}, {"title": "Privacidad", "url": "/privacidad/"}, {"title": "Estudiantes", "url": "/historias/"}, {"title": "Hola", "url": "/hola/"}], "socials": [{"icon": "icon-twt", "url": "https://twitter.com/platzi"}, {"icon": "icon-youtube-play", "url": "https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ"}, {"icon": "icon-fcbk", "url": "https://facebook.com/platzi"}, {"icon": "icon-instagram", "url": "https://www.instagram.com/platzi/"}], "awards": [{"logo": "https://static.platzi.com/static/images/footer/yc.png", "name": "Y Combinator", "url": "https://platzi.com/blog/platzi-y-combinator/"}, {"logo": "https://static.platzi.com/static/images/footer/asugsv.png", "name": "ASU + GSV Summit", "url": "https://platzi.com/blog/platzi-gana-premio-educacion/"}], "referalUrl": false, "lastCourse": [{"approved": "", "badge": "", "career": "", "completed": 0, "id": "", "exam_url": "", " ...
#             var lang = "es";
#         </script><!-- script to load browser based polyfills --><script src="https://cdn.polyfill.io/v2/polyfill.min.js"></script><script defer async>
#             // display a warning in the console
#             console.log('%cStop!', 'color: red;font-size:2.5rem;font-weight:bold;');
#             console.log('%cThis is a browser feature intended for developers. If someone told you to copy-paste something here to enable a Platzi feature or "hack" someone\'s account, it is a scam and will give them access to your Platzi account.', 'font-size:1.25rem;line-height:1.1;margin-top:.5em');
#         </script></head><body><div id="contact-us-modal"></div><div id="header-v2"><div data-reactroot="" data-reactid="1" data-react-checksum="2091602216"><div data-reactid="2"></div><div class="Header-v2 Header-v2-content" data-reactid="3"><div class="Logo" data-reactid="4"><a href="/" title="Platzi.com" data-reactid="5"><img src="data:image/png;base64,..." srcset="data:image/png;base64,... 1x, data:image/png;base64,... 2x" class="Logo-full" alt="Platzi.com" data-reactid="6"/></a></div><div class="Nav-header" data-reactid="7"><div class="Plive" data-reactid="8"></div><div class="Actionsv2" data-reactid="9"><div data-reactid="10"><div class="Actionsv2-menu" data-reactid="11"><div class="isDesktop" data-reactid="12"><span data-reactid="13">Iniciar mi plan</span></div><div class="isMobile" data-reactid="14"><span data-reactid="15">Planes</span></div><i class="icon-arrow-down toggle-down" data-reactid="16"></i></div></div></div><div class="Menu" data-reactid="17"><div class="Menu-dropdown" data-reactid="18"><div class="Menu-title" data-reactid="19"><span data-reactid="20">Menú</span></div></div><div class="Menu-content" data-reactid="21"><div data-reactid="22"><ul class="Menu-list" data-reactid="23"><li class="Menu-list-item" data-reactid="24"><a href="/cursos/" data-reactid="25"><div data-reactid="26">Cursos</div></a></li><li class="Menu-list-item" data-reactid="27"><div data-reactid="28"><div data-reactid="29">Contáctanos</div></div></li><li class="Menu-list-item" data-reactid="30"><a href="/blog/" data-reactid="31"><div data-reactid="32">Blog</div></a></li><li class="Menu-list-item" data-reactid="33"><a href="/agenda/" data-reactid="34"><div data-reactid="35">Agenda</div></a></li><li class="Menu-list-item" data-reactid="36"><a href="/foro/" data-reactid="37"><div data-reactid="38">Foro</div></a></li></ul></div></div></div><div class="ButtonLogin showButton" data-reactid="39"><div data-reactid="40"><a href="/login/" class="btn btn-green btn--small" data-reactid="41"><span data-reactid="42">Iniciar sesión</span></a></div></div><div class="MiniSearch is-tablet" data-reactid="43"><div class="MiniSearch-button MiniSearch-show" data-reactid="44"><span class="icon-search" data-reactid="45"></span></div></div><div class="MiniSearch is-desktop" data-reactid="46"><div class="Searchv" data-reactid="47"><div class="Searchv-content" data-reactid="48"><form action="/search/" class="" data-reactid="49"><input type="text" placeholder="Buscar en Platzi" name="search" autocomplete="off" data-reactid="50"/><button class="Searchv-icon" data-reactid="51"><span class="icon-search" data-reactid="52"></span></button></form></div><div class="Searchv-results" data-reactid="53"></div></div></div></div></div></div></div><input type='hidden' name='csrfmiddlewaretoken' value='Z8KMrzRkiKAC1ezr9dGsuzvV0rxgzWoO7udwDe0Ke8rslAjPtThBmLGy7CHNfB9K' /><!-- <div class="LiveBanner-title icon-micro">Estamos <strong class="LiveBanner-highlight">en vivo</strong></div> --><section id="home-v3"><div class="Layout" data-reactroot="" data-reactid="1" data-react-checksum="-1275977851"><div data-reactid="2"></div><div data-reactid="3"></div><article class="Hero" data-reactid="4"><div class="row u-row-wrapper center-xs" data-reactid="5"><div class="col-xs-12 col-sm-10 col-md-9" data-reactid="6"><div class="Hero-learn" data-reactid="7"><div class="Hero-title" data-reactid="8"><div class="is-cooper-book Hero-copy" data-reactid="9"><span data-reactid="10">Aprende:</span></div><div class="Hero-more" data-reactid="11"><div class="AnimatedCareer" data-reactid="12"><figure data-reactid="13"><img src="https://static.platzi.com/media/career-banner/badge-carrera-fundamentos.png" alt="Fundamentos de Programación" width="30" data-reactid="14"/></figure><div class="AnimatedCareer-title" data-reactid="15">Fundamentos de Programación</div><a href="/fundamentos-programacion/" class="AnimatedCareer-url" data-reactid="16"></a></div><div class="is-cooper-book Hero-careers" data-reactid="17"><sp ...
# Soy Carolina. Nací en Brasil, crecí en Honduras y estudié en una escuela bilingüe.  A los </div></div><div class="PostCard-author" data-reactid="1229"><figure data-reactid="1230"><img alt="CaroB" src="https://static.platzi.com/media/avatars/avatars/carolina-boquin-espirilla_0136426c-82cf-402b-a58e-b925930ef5f9.JPG" height="20" data-reactid="1231"/></figure><span data-reactid="1232">CaroB</span></div></div></article><article class="PostCard-container" data-reactid="1233"><div class="PostCard" data-reactid="1234"><a href="/blog/platziconf-online-2018/" data-reactid="1235"></a><div style="background-image:url(https://static.platzi.com/media/blog/cover-blog-conf-bog-2018-6d7db0a6-bb03-44b3-935f-9d5213685349.jpg);background-color:#98CA3F;" class="PostCard-header" data-reactid="1236"><div class="Star is-level-1 is-medium" data-reactid="1237"><span class="Star-icon icon-thumbs-up" data-reactid="1238"></span><span class="Star-number" data-reactid="1239">22</span></div></div><div class="PostCard-body" data-reactid="1240"><h3 data-reactid="1241">Todo lo que debes saber sobre PlatziConf Online 2018</h3><div class="PostCard-content" data-reactid="1242">Tras nuestra edición de PlatziConf 2018 en CDMX, el turno ahora es para Bogotá.
# Aprende a crear productos digitales exitosos con el conocimiento de expertos en </div></div><div class="PostCard-author" data-reactid="1243"><figure data-reactid="1244"><img alt="lauravaron" src="https://static.platzi.com/media/avatars/avatars/lauravaron_fa09062d-8641-4b84-b5ca-0f45ccbcff0e.jpeg" height="20" data-reactid="1245"/></figure><span data-reactid="1246">lauravaron</span></div></div></article><article class="PostCard-container" data-reactid="1247"><div class="PostCard" data-reactid="1248"><a href="/blog/menos-grupos-de-whatsapp-mas-espacios-de-trabajo-en-slack/" data-reactid="1249"></a><div style="background-image:url(https://static.platzi.com/media/blog/pexels-photo-430205-ef00e254-1d51-468b-bb5d-a1e4ed35ceca.jpeg);background-color:#98CA3F;" class="PostCard-header" data-reactid="1250"><div class="Star is-level-1 is-medium" data-reactid="1251"><span class="Star-icon icon-thumbs-up" data-reactid="1252"></span><span class="Star-number" data-reactid="1253">37</span></div></div><div class="PostCard-body" data-reactid="1254"><h3 data-reactid="1255">Menos grupos de WhatsApp, más espacios de trabajo en Slack</h3><div class="PostCard-content" data-reactid="1256">En mis últimos dos trabajos tuve la oportunidad de observar atónito cómo los equipos de comunicación y marketing usaban grupos de WhatsApp con fines profesional</div></div><div class="PostCard-author" data-reactid="1257"><figure data-reactid="1258"><img alt="ricardobarra" src="https://static.platzi.com/media/avatars/avatars/Chuqui_eb9aab2d-737a-4584-b345-284676b489b0.jpg" height="20" data-reactid="1259"/></figure><span data-reactid="1260">ricardobarra</span></div></div></article></div></div></div></div><div class="Register" data-reactid="1261"><div class="row u-row-wrapper" data-reactid="1262"><div class="col-xs-12 col-sm-6 col-md-4" data-reactid="1263"><p data-reactid="1264"><span data-reactid="1265">Aprende de expertos en programación, diseño, marketing, startups, video y web.</span></p><p class="is-highlighted" data-reactid="1266"><span data-reactid="1267">Suscríbete hoy</span></p><form method="post" class="PreRegisterForm isHomev3" data-reactid="1268"><p class="big PreRegisterForm-title" data-reactid="1269"><strong data-reactid="1270">Regístrate a Platzi</strong></p><div class="row" data-reactid="1271"><div class="col-xs-12 col-sm-12 col-md-12" data-reactid="1272"><div class="form-group" data-reactid="1273"><div class="icon icon-name-circle" data-reactid="1274"></div><input type="text" class="form-control" name="first_name" placeholder="Nombre" data-reactid="1275"/></div></div><div class="col-xs-12 col-sm-12 col-md-12" data-reactid="1276"><div class="form-group" data-reactid="1277"><div class="icon icon-mail-circle" data-reactid="1278"></div><input type="email" class="form-control" name="email" placeholder="Correo electrónico" data-reactid="1279"/></div></div><div class="col-xs-12 col-sm-12 col-md-12" data-reactid="1280"><div class="checkbox" data-reactid="1281"><input type="checkbox" id="tos" class="form-control" name="tos" value="false" data-reactid="1282"/><label class="checkbox-label" for="tos" data-reactid="1283"></label><label data-reactid="1284"><span data-reactid="1285"><!-- react-text: 1286 -->Acepto los <!-- /react-text --><a href="/terminos/" target="_blank" data-reactid="1287"><span data-reactid="1288">Términos de servicio</span></a><!-- react-text: 1289 --> y <!-- /react-text --><a href="/privacidad/" target="_blank" data-reactid="1290"><span data-reactid="1291">Políticas de privacidad</span></a><!-- react-text: 1292 --> de Platzi<!-- /react-text --></span></label></div></div><input type="hidden" value="1" name="landings" data-reactid="1293"/></div><input type="submit" class="btn-green btn--full-width btn--medium" value="Comienza ahora" data-reactid="1294"/></form><p data-reactid="1295"><!-- react-text: 1296 -->O llámanos, en Bogotá al <!-- /react-text --><br data-reactid="1297"/><!-- react-text: 1298 -->+57 316 6126223<!-- /react-text --></p></div></ ...
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&appId=263680607075199&version=v2.0";
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));</script><!-- End SDK de Facebook --><!-- SDK Google Plus --><script type="text/javascript">
#       (function() {
#         var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
#         po.src = 'https://apis.google.com/js/plusone.js?onload=OnLoadCallback';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
#       })();
#     </script><!-- End SDK Google Plus --><!-- SDK Twitter --><script>window.twttr = (function (d, s, id) {
#       var t, js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src= "https://platform.twitter.com/widgets.js";
#       fjs.parentNode.insertBefore(js, fjs);
#       return window.twttr || (t = { _e: [], ready: function (f) { t._e.push(f); } });
#     }(document, "script", "twitter-wjs"));</script><!-- End SDK Twitter --><!-- Google Tag Manager --><noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-KSZ9RW"
#     height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-KSZ9RW');</script><!-- End Google Tag Manager --><!-- Twitter Pixel Compra--><script src="//platform.twitter.com/oct.js" type="text/javascript" async></script><!-- End Twitter Pixel Compra--><script type="text/javascript" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js" async></script><script>
#             var visits = parseInt(window.localStorage.getItem('visits-counter'), 10) || 0;
#             if (visits < 35) {
#                 window.localStorage.setItem('visits-counter', visits + 1)
#             }
#             if (visits === 10 || visits === 20 || visits === 30) {
#                 window.openContact = true;
#             }
#
#         </script><script>
#                 window.contactInfo = {
#                     hasSubscription: false,
#                     isAuthenticated: false,
#                     country: "colombia",
#                     flag: "https://static.platzi.com/static/images/languajes/Colombia.jpg",
#                     isOrganizer: false,
#                     lang: "es",
#                     i18n: {'contactus.title': '¿Tienes dudas o quieres comunicarte con nosotros?', 'contactus.subtitle': 'Elige el medio que más te convenga, te sugerimos ', 'write': 'Escríbenos', 'dm': 'Mensaje Directo', 'telephone': 'Teléfono'},
#                     enabled: false,
#                     accepted_gdpr: false,
#                     userId: '0',
#                 }
#                 window.isHispanic = true
#             </script><script>
#     window.client_data = {"careers": {"95": {"url": "/ciencia/", "title": "Ciencia", "badge": "https://static.platzi.com/media/career-banner/badges-ciencia.png", "amount": 1}, "94": {"url": "/react-native/", "title": "Desarrollo de Apps con React Native", "badge": "https://static.platzi.com/media/career-banner/badges-apps-react-native.png", "amount": 7}, "91": {"url": "/profesional-fotografia/", "title": "Fotograf\u00eda", "badge": "https://static.platzi.com/media/career-banner/badge-fotografia.png", "amount": 4}, "90": {"url": "/produccion-video/", "title": "Producci\u00f3n de Video", "badge": "https://static.platzi.com/media/career-banner/badge-produccion-video.png", "amount": 10}, "89": {"url": "/produccion-audio/", "title": "Producci\u00f3n de Audio", "badge": "https://static.platzi.com/media/career-banner/badge-produccion-audio.png", "amount": 5}, "88": {"url": "/aws/", "title": "Amazon Web Services", "badge": "https://static.platzi.com/media/career-banner/badge-AWS.png", "amount": 4}, "85": {"url": "/transformacion-digital/", "title": "Transformaci\u00f3n Digital", "badge": "https://static.platzi.com/media/career-banner/Badge-transfomacion-digital.png", "amount": 13}, "83": {"url": "/estrategia-marketing/", "title": "Estrategia y Marketing Digital", "badge": "https://static.platzi.com/media/career-banner/badges-estrategia-y-marketing-digital.png", "amount": 5}, "82": {"url": "/gestion-proyectos/", "title": "Gesti\u00f3n de Proyectos", "badge": "https://static.platzi.com/media/career-banner/badges-gestion-de-proyectos.png", "amount": 3}, "81": {"url": "/idioma-ingles/", "title": "Ingl\u00e9s", "badge": "https://static.platzi.com/media/career-banner/Badge-Ingles.png", "amount": 5}, "80": {"url": "/ventas-mercadeo/", "title": "Ventas y Mercadeo", "badge": "https://static.platzi.com/media/career-banner/badges-Ventas-Mercadeo.png", "amount": 7}, "77": {"url": "/desarrollo-angular/", "title": "Desarrollo con Angular", "badge": "https://static.platzi.com/media/career-banner/badges-Angular.png", "amount": 5}, "75": {"url": "/inbound-marketing/", "title": "Inbound Marketing", "badge": "https://static.platzi.com/media/career-banner/Badge-Inbound-Marketing.png", "amount": 12}, "74": {"url": "/carrera-firebase/", "title": "Firebase", "badge": "https://static.platzi.com/media/career-banner/Badge-Carrera-Firebase.png", "amount": 5}, "73": {"url": "/blockchain-criptomonedas/", "title": "Blockchain y Criptomonedas", "badge": "https://static.platzi.com/media/career-banner/Badge-Blockchain-Criptomonedas.png", "amount": 4}, "72": {"url": "/habilidades-blandas/", "title": "Crecimiento Profesional", "badge": "https://static.platzi.com/media/career-banner/badges-Habilidades.png", "amount": 15}, "71": {"url": "/desarrollo-unity/", "title": "Desarrollo con Unity", "badge": "https://static.platzi.com/media/career-banner/badges-CarreraUnity.png", "amount": 5}, "69": {"url": "/diseno-grafico/", "title": "Dise\u00f1o Gr\u00e1fico", "badge": "https://static.platzi.com/media/career-banner/Badge-Diseno-Grafico.png", "amount": 10}, "68": {"url": "/ibm-cloud/", "title": "IBM Cloud", "badge": "https://static.platzi.com/media/career-banner/badges-IBM.png", "amount": 2}, "67": {"url": "/google-cloud/", "title": "Google Cloud Platform", "badge": "https://static.platzi.com/media/career-banner/Badge-Carrera-Google-Cloud-Platform.png", "amount": 3}, "66": {"url": "/matematicas-programacion/", "title": "Matem\u00e1ticas para Programaci\u00f3n", "badge": "https://static.platzi.com/media/career-banner/badge-Matematicas-Programacion.png", "amount": 8}, "65": {"url": "/iot/", "title": "Internet of Things", "badge": "https://static.platzi.com/media/career-banner/Badge-IoT.png", "amount": 5}, "63": {"url": "/data-marketing/", "title": "Marketing Basado en Datos", "badge": "https://static.platzi.com/media/career-banner/badge-marketing-basado-en-datos.png", "amount": 6}, "62": {"url": "/desarrollo-react/", "title": "Frontend con React.JS", "badge": "https://static.plat ...
#     window.endDate = new Date('2018-04-02T00:00:00-04:56');
#     window.currency = {
#       flag: 'https://static.platzi.com/media/flags/CO.png',
#       price: '$799.000',
#       fullPrice: '$890.000',
#     }
#     window.conf = {
#       confEnd: new Date('2018-05-06T09:00:00-05:00'),
#       isConfActive:  false ,
#     };
#     window.preConfDate = new Date('2018-05-05T09:00:00-05:00')
#     window.endBarDate = new Date('2018-09-27T16:00:00-04:56');
#     window.barState = '';
#     window.limitDate = new Date('');
#     window.limitedPromo = {
#       name: '',
#       token: '',
#     };
#   </script><script type="text/javascript" src="https://static.platzi.com/static/js/dll/modules.d86811abb99cf3b15864.js.gz" ></script><script type="text/javascript" src="https://static.platzi.com/static/js/core/home-v3.4dab4b08119b4bd02d27.js.gz" ></script><script type="text/javascript" src="https://static.platzi.com/static/js/d/contact-modal.071242ee7ad31ffa1c09.js.gz" ></script><script type="text/javascript" src="https://static.platzi.com/static/js/core/header-v2.4dab4b08119b4bd02d27.js.gz" ></script><script type="text/javascript" src="https://static.platzi.com/static/js/d/contact-modal.071242ee7ad31ffa1c09.js.gz" ></script><!-- Google Rich Card --><script type="application/ld+json">
#             {
#                 "@context": "http://schema.org",
#                 "@type": "Organization",
#                 "name": "Platzi",
#                 "url": "https://platzi.com/",
#                 "description": "Aprende de expertos en programación, diseño, marketing, startups, video y web. Suscríbete hoy.",
#                 "foundingDate": "2013-01-01",
#                 "founders": [
#                     {
#                         "@type": "Person",
#                         "name": "John Freddy Vega"
#                     },
#                     {
#                         "@type": "Person",
#                         "name": "Christian Van Der Henst"
#                     }
#                 ],
#                 "sameAs": [
#                     "https://www.facebook.com/platzi/",
#                     "https://twitter.com/Platzi",
#                     "https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ",
#                     "https://www.linkedin.com/school/2822346"
#                 ]
#             }
#         </script><!-- Start of LiveChat (www.livechatinc.com) code --><script type="text/javascript">
#             var $zoho=$zoho || {};$zoho.salesiq = $zoho.salesiq ||
#             {widgetcode:"852b603af4c84150cd4f53125b1c530734b9a85b166a9b1ecc95218a4de89824", values:{},ready:function(){}};
#             var d=document;s=d.createElement("script");s.type="text/javascript";s.id="zsiqscript";s.defer=true;
#             s.src="https://salesiq.zoho.com/widget";t=d.getElementsByTagName("script")[0];t.parentNode.insertBefore(s,t);d.write("<div id='zsiqwidget'></div>");
#             </script><!-- End of LiveChat code --></body></html>

# %% [markdown]
# ## Extracción de información del HTML

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

courses_links = soup.select('.Card-link')
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /fundamentos-programacion/
# /desarrollo-php/
# /desarrollo-java/
# /arquitecto/
# /apple-fullstack/
# /desarrollo-android/
# /javascript/
# /multiplataforma/
# /negocios/
# /base-de-datos/
# /backend-ruby/
# /outbound-marketing/
# /servidores/
# /videojuegos/
# /email-marketing/
# /asp-net/
# /datos/
# /inbound-marketing/
# /backend-python/
# /ai/
# /producto/
# /backend-go/
# /desarrollo-wordpress/
# /startups/
# /desarrollo-react/
# /data-marketing/
# /iot/
# /matematicas-programacion/
# /google-cloud/
# /ibm-cloud/
# /diseno-grafico/
# /desarrollo-unity/
# /habilidades-blandas/
# /blockchain-criptomonedas/
# /carrera-firebase/
# /seguridad-informatica/
# /desarrollo-angular/
# /ventas-mercadeo/
# /idioma-ingles/
# /gestion-proyectos/
# /estrategia-marketing/
# /transformacion-digital/
# /aws/
# /produccion-audio/
# /produccion-video/
# /profesional-fotografia/
# /react-native/
# /ciencia/

# %% [markdown]
# ## Series

# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# ## DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23]})

frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74, 38, 39],
                           [34, 32, 32],
                           [23, 39, 23]], columns=[1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# ## Read data

# %%
pd.options.display.max_rows = 10

el_universal = pd.read_csv('web_scrapper/eluniversal_2018_11_08_articles.csv',encoding='ISO-8859-1' )

el_universal
# Out:
#                                                   body  \
# 0    \r\nTal es la desesperación en el conjunto de ...
# 1    \r\nCosas extrañas pasan con el futbol, deport...
# 2    \r\nCiudad de México.- Este día, el grupo parl...
# 3    Al ser estrellas de la farándula nacional, fam...
# 4    \r\nLa Selección Mexicana dio a conocer la lis...
# ..                                                 ...
# 122  La actriz Salma Hayek sorprendió con un espect...
# 123  Cada tres años se repite la misma historia en ...
# 124  \r\nEn la discusión de la emisión de esta sema...
# 125  Lourdes León, hija de Madonna, optó por un atr...
# 126  \r\n[email protected] \r\nSabemos que la playa...
#
#                                                  title  \
# 0                             Nadie quiere ir a Chivas
# 1                     ¿Por qué ahora contra el futbol?
# 2    ¿Qué dice la iniciativa que presentó Morena pa...
# 3                   Las mamás luchonas de la farándula
# 4       Lista la convocatoria de la Selección Mexicana
# ..                                                 ...
# 122                                                NaN
# 123                      La eterna deuda de la capital
# 124  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# 125                                                NaN
# 126       10 hoteles para celebrar Navidad en Acapulco
#
#                                                    url
# 0    http://www.eluniversal.com.mx/universal-deport...
# 1    https://www.eluniversal.com.mx/columna/gerardo...
# 2    http://www.eluniversal.com.mx/nacion/seguridad...
# 3    http://www.unionjalisco.mx/articulo/2018/11/08...
# 4    http://www.eluniversal.com.mx/universal-deport...
# ..                                                 ...
# 122  https://www.viveusa.mx/showbiz/salma-hayek-cam...
# 123  http://sanluis.eluniversal.com.mx/metropoli/08...
# 124  http://www.eluniversal.com.mx/nacion/sociedad/...
# 125  https://www.viveusa.mx/showbiz/hija-de-madonna...
# 126  http://www.eluniversal.com.mx/destinos/10-hote...
#
# [127 rows x 3 columns]

# %% [markdown]
# ## Index and selection

# %%
# dictionary like

el_universal['title']
# Out:
# 0                               Nadie quiere ir a Chivas
# 1                       ¿Por qué ahora contra el futbol?
# 2      ¿Qué dice la iniciativa que presentó Morena pa...
# 3                     Las mamás luchonas de la farándula
# 4         Lista la convocatoria de la Selección Mexicana
#                              ...
# 122                                                  NaN
# 123                        La eterna deuda de la capital
# 124    "¿Traes los ojos rojos?" "Con los de Enfrente"...
# 125                                                  NaN
# 126         10 hoteles para celebrar Navidad en Acapulco
# Name: title, Length: 127, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title  \
# 0                             Nadie quiere ir a Chivas
# 1                     ¿Por qué ahora contra el futbol?
# 2    ¿Qué dice la iniciativa que presentó Morena pa...
# 3                   Las mamás luchonas de la farándula
# 4       Lista la convocatoria de la Selección Mexicana
# ..                                                 ...
# 122                                                NaN
# 123                      La eterna deuda de la capital
# 124  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# 125                                                NaN
# 126       10 hoteles para celebrar Navidad en Acapulco
#
#                                                    url
# 0    http://www.eluniversal.com.mx/universal-deport...
# 1    https://www.eluniversal.com.mx/columna/gerardo...
# 2    http://www.eluniversal.com.mx/nacion/seguridad...
# 3    http://www.unionjalisco.mx/articulo/2018/11/08...
# 4    http://www.eluniversal.com.mx/universal-deport...
# ..                                                 ...
# 122  https://www.viveusa.mx/showbiz/salma-hayek-cam...
# 123  http://sanluis.eluniversal.com.mx/metropoli/08...
# 124  http://www.eluniversal.com.mx/nacion/sociedad/...
# 125  https://www.viveusa.mx/showbiz/hija-de-madonna...
# 126  http://www.eluniversal.com.mx/destinos/10-hote...
#
# [127 rows x 2 columns]

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \r\n\r\nAlejandro I, en el apogeo del autorita...
# 11  \r\nEl comisionado para la Protección contra R...
# 12  Aracely Arámbula y Arturo Carmona estuvieron j...
# 13  El gobernador de Puebla, Antonio Gali Fayad, i...
# 14  \r\nDespués de comer, el cuerpo transforma las...
#
#                                                 title  \
# 10                             AMLO vs. Suprema Corte
# 11  Realizan operativo por rata en Starbucks de Me...
# 12                     Los amores de Aracely Arámbula
# 13  Puebla equipa todos los preescolares públicos ...
# 14  Alimentos para bajar los niveles de triglicéri...
#
#                                                   url
# 10  https://www.eluniversal.com.mx/articulo/mario-...
# 11  http://www.eluniversal.com.mx/metropoli/edomex...
# 12  http://www.unionpuebla.mx/articulo/2018/11/08/...
# 13  http://www.unionpuebla.mx/articulo/2018/11/08/...
# 14  http://www.eluniversal.com.mx/menu/alimentos-p...

# %%
el_universal.iloc[66]['title']
# Out:
# nan

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \r\nTal es la desesperación en el conjunto de ...
# 1    \r\nCosas extrañas pasan con el futbol, deport...
# 2    \r\nCiudad de México.- Este día, el grupo parl...
# 3    Al ser estrellas de la farándula nacional, fam...
# 4    \r\nLa Selección Mexicana dio a conocer la lis...
# Name: body, dtype: object

# %%
el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \r\nTal es la desesperación en el conjunto de ...
# 1    \r\nCosas extrañas pasan con el futbol, deport...
# 2    \r\nCiudad de México.- Este día, el grupo parl...
# 3    Al ser estrellas de la farándula nacional, fam...
# 4    \r\nLa Selección Mexicana dio a conocer la lis...
# ..                                                 ...
# 122  La actriz Salma Hayek sorprendió con un espect...
# 123  Cada tres años se repite la misma historia en ...
# 124  \r\nEn la discusión de la emisión de esta sema...
# 125  Lourdes León, hija de Madonna, optó por un atr...
# 126  \r\n[email protected] \r\nSabemos que la playa...
#
#                                                  title
# 0                             Nadie quiere ir a Chivas
# 1                     ¿Por qué ahora contra el futbol?
# 2    ¿Qué dice la iniciativa que presentó Morena pa...
# 3                   Las mamás luchonas de la farándula
# 4       Lista la convocatoria de la Selección Mexicana
# ..                                                 ...
# 122                                                NaN
# 123                      La eterna deuda de la capital
# 124  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# 125                                                NaN
# 126       10 hoteles para celebrar Navidad en Acapulco
#
# [127 rows x 2 columns]

# %% [markdown]
# ## Data wrangling

# %%
# 1. Añadir newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                   body  \
# 0    \r\nTal es la desesperación en el conjunto de ...
# 1    \r\nCosas extrañas pasan con el futbol, deport...
# 2    \r\nCiudad de México.- Este día, el grupo parl...
# 3    Al ser estrellas de la farándula nacional, fam...
# 4    \r\nLa Selección Mexicana dio a conocer la lis...
# ..                                                 ...
# 122  La actriz Salma Hayek sorprendió con un espect...
# 123  Cada tres años se repite la misma historia en ...
# 124  \r\nEn la discusión de la emisión de esta sema...
# 125  Lourdes León, hija de Madonna, optó por un atr...
# 126  \r\n[email protected] \r\nSabemos que la playa...
#
#                                                  title  \
# 0                             Nadie quiere ir a Chivas
# 1                     ¿Por qué ahora contra el futbol?
# 2    ¿Qué dice la iniciativa que presentó Morena pa...
# 3                   Las mamás luchonas de la farándula
# 4       Lista la convocatoria de la Selección Mexicana
# ..                                                 ...
# 122                                                NaN
# 123                      La eterna deuda de la capital
# 124  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# 125                                                NaN
# 126       10 hoteles para celebrar Navidad en Acapulco
#
#                                                    url newspaper_uid
# 0    http://www.eluniversal.com.mx/universal-deport...   eluniversal
# 1    https://www.eluniversal.com.mx/columna/gerardo...   eluniversal
# 2    http://www.eluniversal.com.mx/nacion/seguridad...   eluniversal
# 3    http://www.unionjalisco.mx/articulo/2018/11/08...   eluniversal
# 4    http://www.eluniversal.com.mx/universal-deport...   eluniversal
# ..                                                 ...           ...
# 122  https://www.viveusa.mx/showbiz/salma-hayek-cam...   eluniversal
# 123  http://sanluis.eluniversal.com.mx/metropoli/08...   eluniversal
# 124  http://www.eluniversal.com.mx/nacion/sociedad/...   eluniversal
# 125  https://www.viveusa.mx/showbiz/hija-de-madonna...   eluniversal
# 126  http://www.eluniversal.com.mx/destinos/10-hote...   eluniversal
#
# [127 rows x 4 columns]

# %%
# 2. Obtener el host
from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \r\nTal es la desesperación en el conjunto de ...
# 1    \r\nCosas extrañas pasan con el futbol, deport...
# 2    \r\nCiudad de México.- Este día, el grupo parl...
# 3    Al ser estrellas de la farándula nacional, fam...
# 4    \r\nLa Selección Mexicana dio a conocer la lis...
# ..                                                 ...
# 122  La actriz Salma Hayek sorprendió con un espect...
# 123  Cada tres años se repite la misma historia en ...
# 124  \r\nEn la discusión de la emisión de esta sema...
# 125  Lourdes León, hija de Madonna, optó por un atr...
# 126  \r\n[email protected] \r\nSabemos que la playa...
#
#                                                  title  \
# 0                             Nadie quiere ir a Chivas
# 1                     ¿Por qué ahora contra el futbol?
# 2    ¿Qué dice la iniciativa que presentó Morena pa...
# 3                   Las mamás luchonas de la farándula
# 4       Lista la convocatoria de la Selección Mexicana
# ..                                                 ...
# 122                                                NaN
# 123                      La eterna deuda de la capital
# 124  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# 125                                                NaN
# 126       10 hoteles para celebrar Navidad en Acapulco
#
#                                                    url newspaper_uid  \
# 0    http://www.eluniversal.com.mx/universal-deport...   eluniversal
# 1    https://www.eluniversal.com.mx/columna/gerardo...   eluniversal
# 2    http://www.eluniversal.com.mx/nacion/seguridad...   eluniversal
# 3    http://www.unionjalisco.mx/articulo/2018/11/08...   eluniversal
# 4    http://www.eluniversal.com.mx/universal-deport...   eluniversal
# ..                                                 ...           ...
# 122  https://www.viveusa.mx/showbiz/salma-hayek-cam...   eluniversal
# 123  http://sanluis.eluniversal.com.mx/metropoli/08...   eluniversal
# 124  http://www.eluniversal.com.mx/nacion/sociedad/...   eluniversal
# 125  https://www.viveusa.mx/showbiz/hija-de-madonna...   eluniversal
# 126  http://www.eluniversal.com.mx/destinos/10-hote...   eluniversal
#
#                            host
# 0        www.eluniversal.com.mx
# 1        www.eluniversal.com.mx
# 2        www.eluniversal.com.mx
# 3           www.unionjalisco.mx
# 4        www.eluniversal.com.mx
# ..                          ...
# 122              www.viveusa.mx
# 123  sanluis.eluniversal.com.mx
# 124      www.eluniversal.com.mx
# 125              www.viveusa.mx
# 126      www.eluniversal.com.mx
#
# [127 rows x 5 columns]

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx    65
# de10.com.mx               10
# www.viveusa.mx             9
# www.elbotiquin.mx          9
# www.elgrafico.mx           5
#                           ..
# www.unionyucatan.mx        2
# www.unioncdmx.mx           2
# www.unionguanajuato.mx     2
# www.unionedomex.mx         2
# www.union-morelos.mx       1
# Name: host, Length: 15, dtype: int64

# %% [markdown]
# ## Missing data

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles = (el_universal[missing_titles_mask]['url']
                     .str.extract(r'(?P<missing_titles>[^/]+)$')
                     .applymap(lambda title: title.split('-'))
                     .applymap(lambda title_word_list: ' '.join(title_word_list))
                )
missing_titles
# Out:
#                                         missing_titles
# 8    policia asesina su suegro y cunado tras discus...
# 25   la polemica detras del osezno que escala una p...
# 31        la enfermedad que llena la boca de dientes 0
# 42                    como se usa una copita menstrual
# 46   10 frases para enamorarte de lo que el viento ...
# ..                                                 ...
# 117        tener sexo casual puede provocarte ansiedad
# 118  im love my car la historia de la cancion que d...
# 120  nueva york abre museo de la pizza y promete se...
# 122  salma hayek cambia de look se transforma en pe...
# 125  hija de madonna deslumbra con braless y transp...
#
# [33 rows x 1 columns]

# %%
el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']

# %% [markdown]
# ## Additional cleanup

# %%
# 4. añadir uid a las filas
import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
       )

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)

el_universal
# Out:
#                                                                                body  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76  \r\nTal es la desesperación en el conjunto de ...
# e16a7135bb23500a6118b51ed0b4dd6a  \r\nCosas extrañas pasan con el futbol, deport...
# 05e551d8ca11592f252b63b2d325ae8d  \r\nCiudad de México.- Este día, el grupo parl...
# d94e3b0876763b2821d240e6161139b5  Al ser estrellas de la farándula nacional, fam...
# f50e8181c917ed09a756ae4c8a40d0bc  \r\nLa Selección Mexicana dio a conocer la lis...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  La actriz Salma Hayek sorprendió con un espect...
# 954628011a22c7da9f0640335d8e518b  Cada tres años se repite la misma historia en ...
# 166f1fe9e543da7f28a260fa514edd77  \r\nEn la discusión de la emisión de esta sema...
# ad03234574db64e1245984712df0626c  Lourdes León, hija de Madonna, optó por un atr...
# c7d70d8b28d5ac7d149cd14dd4c983cf  \r\n[email protected] \r\nSabemos que la playa...
#
#                                                                               title  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76                           Nadie quiere ir a Chivas
# e16a7135bb23500a6118b51ed0b4dd6a                   ¿Por qué ahora contra el futbol?
# 05e551d8ca11592f252b63b2d325ae8d  ¿Qué dice la iniciativa que presentó Morena pa...
# d94e3b0876763b2821d240e6161139b5                 Las mamás luchonas de la farándula
# f50e8181c917ed09a756ae4c8a40d0bc     Lista la convocatoria de la Selección Mexicana
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  salma hayek cambia de look se transforma en pe...
# 954628011a22c7da9f0640335d8e518b                      La eterna deuda de la capital
# 166f1fe9e543da7f28a260fa514edd77  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# ad03234574db64e1245984712df0626c  hija de madonna deslumbra con braless y transp...
# c7d70d8b28d5ac7d149cd14dd4c983cf       10 hoteles para celebrar Navidad en Acapulco
#
#                                                                                 url  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76  http://www.eluniversal.com.mx/universal-deport...
# e16a7135bb23500a6118b51ed0b4dd6a  https://www.eluniversal.com.mx/columna/gerardo...
# 05e551d8ca11592f252b63b2d325ae8d  http://www.eluniversal.com.mx/nacion/seguridad...
# d94e3b0876763b2821d240e6161139b5  http://www.unionjalisco.mx/articulo/2018/11/08...
# f50e8181c917ed09a756ae4c8a40d0bc  http://www.eluniversal.com.mx/universal-deport...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  https://www.viveusa.mx/showbiz/salma-hayek-cam...
# 954628011a22c7da9f0640335d8e518b  http://sanluis.eluniversal.com.mx/metropoli/08...
# 166f1fe9e543da7f28a260fa514edd77  http://www.eluniversal.com.mx/nacion/sociedad/...
# ad03234574db64e1245984712df0626c  https://www.viveusa.mx/showbiz/hija-de-madonna...
# c7d70d8b28d5ac7d149cd14dd4c983cf  http://www.eluniversal.com.mx/destinos/10-hote...
#
#                                  newspaper_uid                        host
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76   eluniversal      www.eluniversal.com.mx
# e16a7135bb23500a6118b51ed0b4dd6a   eluniversal      www.eluniversal.com.mx
# 05e551d8ca11592f252b63b2d325ae8d   eluniversal      www.eluniversal.com.mx
# d94e3b0876763b2821d240e6161139b5   eluniversal         www.unionjalisco.mx
# f50e8181c917ed09a756ae4c8a40d0bc   eluniversal      www.eluniversal.com.mx
# ...                                        ...                         ...
# 4254fbe40b509691ede796c3841f1eac   eluniversal              www.viveusa.mx
# 954628011a22c7da9f0640335d8e518b   eluniversal  sanluis.eluniversal.com.mx
# 166f1fe9e543da7f28a260fa514edd77   eluniversal      www.eluniversal.com.mx
# ad03234574db64e1245984712df0626c   eluniversal              www.viveusa.mx
# c7d70d8b28d5ac7d149cd14dd4c983cf   eluniversal      www.eluniversal.com.mx
#
# [127 rows x 5 columns]

# %%
stripped_body = (el_universal
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ' '), letters)))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\r', ' '), letters)))
                     .apply(lambda letters: ''.join(letters))
                )

el_universal['body'] = stripped_body

el_universal
# Out:
#                                                                                body  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76    Tal es la desesperación en el conjunto de la...
# e16a7135bb23500a6118b51ed0b4dd6a    Cosas extrañas pasan con el futbol, deporte ...
# 05e551d8ca11592f252b63b2d325ae8d    Ciudad de México.- Este día, el grupo parlam...
# d94e3b0876763b2821d240e6161139b5  Al ser estrellas de la farándula nacional, fam...
# f50e8181c917ed09a756ae4c8a40d0bc    La Selección Mexicana dio a conocer la lista...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  La actriz Salma Hayek sorprendió con un espect...
# 954628011a22c7da9f0640335d8e518b  Cada tres años se repite la misma historia en ...
# 166f1fe9e543da7f28a260fa514edd77    En la discusión de la emisión de esta semana...
# ad03234574db64e1245984712df0626c  Lourdes León, hija de Madonna, optó por un atr...
# c7d70d8b28d5ac7d149cd14dd4c983cf    [email protected]   Sabemos que la playa es ...
#
#                                                                               title  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76                           Nadie quiere ir a Chivas
# e16a7135bb23500a6118b51ed0b4dd6a                   ¿Por qué ahora contra el futbol?
# 05e551d8ca11592f252b63b2d325ae8d  ¿Qué dice la iniciativa que presentó Morena pa...
# d94e3b0876763b2821d240e6161139b5                 Las mamás luchonas de la farándula
# f50e8181c917ed09a756ae4c8a40d0bc     Lista la convocatoria de la Selección Mexicana
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  salma hayek cambia de look se transforma en pe...
# 954628011a22c7da9f0640335d8e518b                      La eterna deuda de la capital
# 166f1fe9e543da7f28a260fa514edd77  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# ad03234574db64e1245984712df0626c  hija de madonna deslumbra con braless y transp...
# c7d70d8b28d5ac7d149cd14dd4c983cf       10 hoteles para celebrar Navidad en Acapulco
#
#                                                                                 url  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76  http://www.eluniversal.com.mx/universal-deport...
# e16a7135bb23500a6118b51ed0b4dd6a  https://www.eluniversal.com.mx/columna/gerardo...
# 05e551d8ca11592f252b63b2d325ae8d  http://www.eluniversal.com.mx/nacion/seguridad...
# d94e3b0876763b2821d240e6161139b5  http://www.unionjalisco.mx/articulo/2018/11/08...
# f50e8181c917ed09a756ae4c8a40d0bc  http://www.eluniversal.com.mx/universal-deport...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  https://www.viveusa.mx/showbiz/salma-hayek-cam...
# 954628011a22c7da9f0640335d8e518b  http://sanluis.eluniversal.com.mx/metropoli/08...
# 166f1fe9e543da7f28a260fa514edd77  http://www.eluniversal.com.mx/nacion/sociedad/...
# ad03234574db64e1245984712df0626c  https://www.viveusa.mx/showbiz/hija-de-madonna...
# c7d70d8b28d5ac7d149cd14dd4c983cf  http://www.eluniversal.com.mx/destinos/10-hote...
#
#                                  newspaper_uid                        host
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76   eluniversal      www.eluniversal.com.mx
# e16a7135bb23500a6118b51ed0b4dd6a   eluniversal      www.eluniversal.com.mx
# 05e551d8ca11592f252b63b2d325ae8d   eluniversal      www.eluniversal.com.mx
# d94e3b0876763b2821d240e6161139b5   eluniversal         www.unionjalisco.mx
# f50e8181c917ed09a756ae4c8a40d0bc   eluniversal      www.eluniversal.com.mx
# ...                                        ...                         ...
# 4254fbe40b509691ede796c3841f1eac   eluniversal              www.viveusa.mx
# 954628011a22c7da9f0640335d8e518b   eluniversal  sanluis.eluniversal.com.mx
# 166f1fe9e543da7f28a260fa514edd77   eluniversal      www.eluniversal.com.mx
# ad03234574db64e1245984712df0626c   eluniversal              www.viveusa.mx
# c7d70d8b28d5ac7d149cd14dd4c983cf   eluniversal      www.eluniversal.com.mx
#
# [127 rows x 5 columns]

# %% [markdown]
# ## Data enrichment

# %%
# 6 tokenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

# nltk.download('punkt')
# nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
               .dropna()
               .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
               .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
               .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
               .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
               .apply(lambda valid_word_list: len(valid_word_list))
           )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')

el_universal
# Out:
#                                                                                body  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76    Tal es la desesperación en el conjunto de la...
# e16a7135bb23500a6118b51ed0b4dd6a    Cosas extrañas pasan con el futbol, deporte ...
# 05e551d8ca11592f252b63b2d325ae8d    Ciudad de México.- Este día, el grupo parlam...
# d94e3b0876763b2821d240e6161139b5  Al ser estrellas de la farándula nacional, fam...
# f50e8181c917ed09a756ae4c8a40d0bc    La Selección Mexicana dio a conocer la lista...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  La actriz Salma Hayek sorprendió con un espect...
# 954628011a22c7da9f0640335d8e518b  Cada tres años se repite la misma historia en ...
# 166f1fe9e543da7f28a260fa514edd77    En la discusión de la emisión de esta semana...
# ad03234574db64e1245984712df0626c  Lourdes León, hija de Madonna, optó por un atr...
# c7d70d8b28d5ac7d149cd14dd4c983cf    [email protected]   Sabemos que la playa es ...
#
#                                                                               title  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76                           Nadie quiere ir a Chivas
# e16a7135bb23500a6118b51ed0b4dd6a                   ¿Por qué ahora contra el futbol?
# 05e551d8ca11592f252b63b2d325ae8d  ¿Qué dice la iniciativa que presentó Morena pa...
# d94e3b0876763b2821d240e6161139b5                 Las mamás luchonas de la farándula
# f50e8181c917ed09a756ae4c8a40d0bc     Lista la convocatoria de la Selección Mexicana
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  salma hayek cambia de look se transforma en pe...
# 954628011a22c7da9f0640335d8e518b                      La eterna deuda de la capital
# 166f1fe9e543da7f28a260fa514edd77  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# ad03234574db64e1245984712df0626c  hija de madonna deslumbra con braless y transp...
# c7d70d8b28d5ac7d149cd14dd4c983cf       10 hoteles para celebrar Navidad en Acapulco
#
#                                                                                 url  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76  http://www.eluniversal.com.mx/universal-deport...
# e16a7135bb23500a6118b51ed0b4dd6a  https://www.eluniversal.com.mx/columna/gerardo...
# 05e551d8ca11592f252b63b2d325ae8d  http://www.eluniversal.com.mx/nacion/seguridad...
# d94e3b0876763b2821d240e6161139b5  http://www.unionjalisco.mx/articulo/2018/11/08...
# f50e8181c917ed09a756ae4c8a40d0bc  http://www.eluniversal.com.mx/universal-deport...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  https://www.viveusa.mx/showbiz/salma-hayek-cam...
# 954628011a22c7da9f0640335d8e518b  http://sanluis.eluniversal.com.mx/metropoli/08...
# 166f1fe9e543da7f28a260fa514edd77  http://www.eluniversal.com.mx/nacion/sociedad/...
# ad03234574db64e1245984712df0626c  https://www.viveusa.mx/showbiz/hija-de-madonna...
# c7d70d8b28d5ac7d149cd14dd4c983cf  http://www.eluniversal.com.mx/destinos/10-hote...
#
#                                  newspaper_uid                        host  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76   eluniversal      www.eluniversal.com.mx
# e16a7135bb23500a6118b51ed0b4dd6a   eluniversal      www.eluniversal.com.mx
# 05e551d8ca11592f252b63b2d325ae8d   eluniversal      www.eluniversal.com.mx
# d94e3b0876763b2821d240e6161139b5   eluniversal         www.unionjalisco.mx
# f50e8181c917ed09a756ae4c8a40d0bc   eluniversal      www.eluniversal.com.mx
# ...                                        ...                         ...
# 4254fbe40b509691ede796c3841f1eac   eluniversal              www.viveusa.mx
# 954628011a22c7da9f0640335d8e518b   eluniversal  sanluis.eluniversal.com.mx
# 166f1fe9e543da7f28a260fa514edd77   eluniversal      www.eluniversal.com.mx
# ad03234574db64e1245984712df0626c   eluniversal              www.viveusa.mx
# c7d70d8b28d5ac7d149cd14dd4c983cf   eluniversal      www.eluniversal.com.mx
#
#                                   n_tokens_title  n_tokens_body
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76               4             77
# e16a7135bb23500a6118b51ed0b4dd6a               2            251
# 05e551d8ca11592f252b63b2d325ae8d               6            519
# d94e3b0876763b2821d240e6161139b5               3            125
# f50e8181c917ed09a756ae4c8a40d0bc               4            107
# ...                                          ...            ...
# 4254fbe40b509691ede796c3841f1eac               6            293
# 954628011a22c7da9f0640335d8e518b               3           1133
# 166f1fe9e543da7f28a260fa514edd77               5            206
# ad03234574db64e1245984712df0626c               7            153
# c7d70d8b28d5ac7d149cd14dd4c983cf               4            585
#
# [127 rows x 7 columns]

# %% [markdown]
# ## Duplicate values

# %%
# 8. Eliminar duplicados

el_universal['title'].value_counts()
# Out:
# im love my car la historia de la cancion que dividio queen                                           2
# Contrastan opiniones de legisladores sobre debate de regulación de drogas                            1
# 'Tuca' Ferretti ya no hará favores al Tri                                                            1
# Diplomáticos de carrera se rebelan a canciller                                                       1
# Sigue la paridad peso - dólar en tiempo real                                                         1
#                                                                                                     ..
# Por ser "muy bajita" conductora de tráiler posiblemente no alcanzó a frenar en Santa Fe, dice SSP    1
# La piel bien gruesa                                                                                  1
# El molcajete y el metate se resisten a la extinción                                                  1
# La salsa de chapulín que sedujo a tiburones                                                          1
# Caen acciones de bancos por propuesta de quitar comisiones                                           1
# Name: title, Length: 126, dtype: int64

# %%
el_universal[el_universal['title'] == 'im love my car la historia de la cancion que dividio queen']
# Out:
#                                                                                body  \
# uid
# 5f6ddcb99d0f02dbe7689a435f292138   0 % PULSO SOCIAL0 Si ya viste la película Boh...
# d3d9090e1d0b9eb9d779b98ade12eb4a   0 % PULSO SOCIAL0 Si ya viste la película Boh...
#
#                                                                               title  \
# uid
# 5f6ddcb99d0f02dbe7689a435f292138  im love my car la historia de la cancion que d...
# d3d9090e1d0b9eb9d779b98ade12eb4a  im love my car la historia de la cancion que d...
#
#                                                                                 url  \
# uid
# 5f6ddcb99d0f02dbe7689a435f292138  http://de10.com.mx/top-10/2018/11/07/im-love-m...
# d3d9090e1d0b9eb9d779b98ade12eb4a  http://de10.com.mx/top-10/2018/11/08/im-love-m...
#
#                                  newspaper_uid         host  n_tokens_title  \
# uid
# 5f6ddcb99d0f02dbe7689a435f292138   eluniversal  de10.com.mx               8
# d3d9090e1d0b9eb9d779b98ade12eb4a   eluniversal  de10.com.mx               8
#
#                                   n_tokens_body
# uid
# 5f6ddcb99d0f02dbe7689a435f292138             26
# d3d9090e1d0b9eb9d779b98ade12eb4a             26

# %%
el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)

# %% [markdown]
# ## Final table

# %%
# Tabla final

el_universal
# Out:
#                                                                                body  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76    Tal es la desesperación en el conjunto de la...
# e16a7135bb23500a6118b51ed0b4dd6a    Cosas extrañas pasan con el futbol, deporte ...
# 05e551d8ca11592f252b63b2d325ae8d    Ciudad de México.- Este día, el grupo parlam...
# d94e3b0876763b2821d240e6161139b5  Al ser estrellas de la farándula nacional, fam...
# f50e8181c917ed09a756ae4c8a40d0bc    La Selección Mexicana dio a conocer la lista...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  La actriz Salma Hayek sorprendió con un espect...
# 954628011a22c7da9f0640335d8e518b  Cada tres años se repite la misma historia en ...
# 166f1fe9e543da7f28a260fa514edd77    En la discusión de la emisión de esta semana...
# ad03234574db64e1245984712df0626c  Lourdes León, hija de Madonna, optó por un atr...
# c7d70d8b28d5ac7d149cd14dd4c983cf    [email protected]   Sabemos que la playa es ...
#
#                                                                               title  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76                           Nadie quiere ir a Chivas
# e16a7135bb23500a6118b51ed0b4dd6a                   ¿Por qué ahora contra el futbol?
# 05e551d8ca11592f252b63b2d325ae8d  ¿Qué dice la iniciativa que presentó Morena pa...
# d94e3b0876763b2821d240e6161139b5                 Las mamás luchonas de la farándula
# f50e8181c917ed09a756ae4c8a40d0bc     Lista la convocatoria de la Selección Mexicana
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  salma hayek cambia de look se transforma en pe...
# 954628011a22c7da9f0640335d8e518b                      La eterna deuda de la capital
# 166f1fe9e543da7f28a260fa514edd77  "¿Traes los ojos rojos?" "Con los de Enfrente"...
# ad03234574db64e1245984712df0626c  hija de madonna deslumbra con braless y transp...
# c7d70d8b28d5ac7d149cd14dd4c983cf       10 hoteles para celebrar Navidad en Acapulco
#
#                                                                                 url  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76  http://www.eluniversal.com.mx/universal-deport...
# e16a7135bb23500a6118b51ed0b4dd6a  https://www.eluniversal.com.mx/columna/gerardo...
# 05e551d8ca11592f252b63b2d325ae8d  http://www.eluniversal.com.mx/nacion/seguridad...
# d94e3b0876763b2821d240e6161139b5  http://www.unionjalisco.mx/articulo/2018/11/08...
# f50e8181c917ed09a756ae4c8a40d0bc  http://www.eluniversal.com.mx/universal-deport...
# ...                                                                             ...
# 4254fbe40b509691ede796c3841f1eac  https://www.viveusa.mx/showbiz/salma-hayek-cam...
# 954628011a22c7da9f0640335d8e518b  http://sanluis.eluniversal.com.mx/metropoli/08...
# 166f1fe9e543da7f28a260fa514edd77  http://www.eluniversal.com.mx/nacion/sociedad/...
# ad03234574db64e1245984712df0626c  https://www.viveusa.mx/showbiz/hija-de-madonna...
# c7d70d8b28d5ac7d149cd14dd4c983cf  http://www.eluniversal.com.mx/destinos/10-hote...
#
#                                  newspaper_uid                        host  \
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76   eluniversal      www.eluniversal.com.mx
# e16a7135bb23500a6118b51ed0b4dd6a   eluniversal      www.eluniversal.com.mx
# 05e551d8ca11592f252b63b2d325ae8d   eluniversal      www.eluniversal.com.mx
# d94e3b0876763b2821d240e6161139b5   eluniversal         www.unionjalisco.mx
# f50e8181c917ed09a756ae4c8a40d0bc   eluniversal      www.eluniversal.com.mx
# ...                                        ...                         ...
# 4254fbe40b509691ede796c3841f1eac   eluniversal              www.viveusa.mx
# 954628011a22c7da9f0640335d8e518b   eluniversal  sanluis.eluniversal.com.mx
# 166f1fe9e543da7f28a260fa514edd77   eluniversal      www.eluniversal.com.mx
# ad03234574db64e1245984712df0626c   eluniversal              www.viveusa.mx
# c7d70d8b28d5ac7d149cd14dd4c983cf   eluniversal      www.eluniversal.com.mx
#
#                                   n_tokens_title  n_tokens_body
# uid
# 2ca7f3c46592f24fc69572df7ab4ff76               4             77
# e16a7135bb23500a6118b51ed0b4dd6a               2            251
# 05e551d8ca11592f252b63b2d325ae8d               6            519
# d94e3b0876763b2821d240e6161139b5               3            125
# f50e8181c917ed09a756ae4c8a40d0bc               4            107
# ...                                          ...            ...
# 4254fbe40b509691ede796c3841f1eac               6            293
# 954628011a22c7da9f0640335d8e518b               3           1133
# 166f1fe9e543da7f28a260fa514edd77               5            206
# ad03234574db64e1245984712df0626c               7            153
# c7d70d8b28d5ac7d149cd14dd4c983cf               4            585
#
# [126 rows x 7 columns]

# %% [markdown]
# ## Descriptive analysis

# %%
clean_eluniversal = pd.read_csv('web_scrapper/Clean_elpais_2018_11_09_articles.csv')
clean_elpais = pd.read_csv('web_scrapper/Clean_eluniversal_2018_11_08_articles.csv')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       37.000000      37.000000
# mean         6.108108     471.000000
# std          2.330758     342.978619
# min          2.000000      51.000000
# 25%          4.000000     280.000000
# 50%          6.000000     381.000000
# 75%          8.000000     531.000000
# max         10.000000    1800.000000

# %%
clean_elpais.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count      126.000000     126.000000
# mean         5.365079     207.452381
# std          1.813739     150.808096
# min          2.000000      26.000000
# 25%          4.000000     106.250000
# 50%          5.000000     170.500000
# 75%          6.000000     250.000000
# max         11.000000    1133.000000

# %%
clean_elpais.loc[clean_elpais['n_tokens_title'] == 0]
# Out:
# Empty DataFrame
# Columns: [uid, body, title, url, newspaper_uid, host, n_tokens_title, n_tokens_body]
# Index: []

# %%
# %matplotlib inline

# %%
clean_elpais['n_tokens_title'].plot(style='b*')
clean_eluniversal['n_tokens_title'].plot(style='r*')

# %%
clean_elpais['n_tokens_body'].plot(style='k.')
clean_eluniversal['n_tokens_body'].plot(style='r.')

# %%
all_newspapers = pd.concat([clean_eluniversal, clean_elpais])

grouped = all_newspapers.groupby('newspaper_uid')

grouped.hist()
# Out:
# newspaper_uid
# elpais         [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min', 'mean', 'max'])
# Out:
#                min        mean   max
# newspaper_uid
# elpais          51  471.000000  1800
# eluniversal     26  207.452381  1133

# %%
grouped.plot()
# Out:
# newspaper_uid
# elpais         AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
