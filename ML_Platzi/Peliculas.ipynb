# %% [markdown]
# # Predicion de ingresospeliculas IMDB

# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
movies=pd.read_csv('peliculas.csv', encoding='UTF-8')

# %%
financials= pd.read_csv ('thenumbers.csv', encoding='UTF-8')

# %%
financials.head()
# Out:
#    Unnamed: 0                                movie_name  domestic_gross  \
# 0           0                                    Avatar       760507625
# 1           1      Star Wars Ep. VII: The Force Awakens       936662225
# 2           2  Pirates of the Caribbean: At World's End       309420425
# 3           3                                   Spectre       200074175
# 4           4                     The Dark Knight Rises       448139099
#
#                                           movie_link  production_budget  \
# 0  http://www.the-numbers.com/movie/Avatar#tab=su...          425000000
# 1  http://www.the-numbers.com/movie/Star-Wars-Ep-...          306000000
# 2  http://www.the-numbers.com/movie/Pirates-of-th...          300000000
# 3  http://www.the-numbers.com/movie/Spectre#tab=s...          300000000
# 4  http://www.the-numbers.com/movie/Dark-Knight-R...          275000000
#
#   release_date  worldwide_gross  \
# 0   12/18/2009       2783918982
# 1   12/18/2015       2058662225
# 2    5/24/2007        963420425
# 3    11/6/2015        879620923
# 4    7/20/2012       1084439099
#
#                                          movie_title
# 0                                            Avatar
# 1  Star Wars: Episode VII - The Force Awakens    ...
# 2          Pirates of the Caribbean: At World's End
# 3                                           Spectre
# 4                             The Dark Knight Rises

# %%
movies.shape
# Out:
# (5043, 19)

# %%
movies_V2=pd.merge(movies,financials,on='movie_title',how='right')

# %%
movies_V2.dtypes== float
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# Unnamed: 0                   False
# movie_name                   False
# domestic_gross               False
# movie_link                   False
# production_budget            False
# release_date                 False
# worldwide_gross              False
# dtype: bool

# %%
movies_V2.dtypes == int
# Out:
# movie_title                  False
# title_year                   False
# color                        False
# aspect_ratio                 False
# duration                     False
# language                     False
# country                      False
# duration.1                   False
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                       False
# imdb_score                   False
# gross                        False
# Unnamed: 0                   False
# movie_name                   False
# domestic_gross               False
# movie_link                   False
# production_budget            False
# release_date                 False
# worldwide_gross              False
# dtype: bool

# %%
num=movies_V2.dtypes== float

# %%
num_cols = [c for c in num.index if num[c]]

# %%
num_cols.append('movie_title')
num_cols.append('cast_total_facebook_likes')
num_cols.append('worldwide_gross')

# %%
num_cols
# Out:
# ['title_year',
#  'aspect_ratio',
#  'duration',
#  'duration.1',
#  'budget',
#  'imdb_score',
#  'gross',
#  'movie_title',
#  'cast_total_facebook_likes',
#  'worldwide_gross']

# %%
movies_V3=movies_V2[num_cols]

# %%
movies_V3.notnull().apply(pd.Series.value_counts)
# Out:
#        title_year  aspect_ratio  duration  duration.1  budget  imdb_score  \
# False          27           274        13          13     335         NaN
# True         4358          4111      4372        4372    4050      4385.0
#
#        gross  movie_title  cast_total_facebook_likes  worldwide_gross
# False    671          NaN                        NaN              NaN
# True    3714       4385.0                     4385.0           4385.0

# %%
(movies_V3 !=0).apply(pd.Series.value_counts)
# Out:
#        title_year  aspect_ratio  duration  duration.1  budget  imdb_score  \
# False         NaN           NaN       NaN         NaN     NaN         NaN
# True       4385.0        4385.0    4385.0      4385.0  4385.0      4385.0
#
#         gross  movie_title  cast_total_facebook_likes  worldwide_gross
# False     NaN          NaN                         27              281
# True   4385.0       4385.0                       4358             4104

# %%
available =((movies_V3!=0)&(movies_V3.notnull()))
available.all(axis=1).value_counts()
# Out:
# True     3408
# False     977
# dtype: int64

# %%
mask=available['worldwide_gross']

# %%
movies_V3= movies_V3[mask]
# Out:
# C:\Users\eslop\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
((movies_V3 != 0) & (movies_V3.notnull())).worldwide_gross.value_counts()
# Out:
# True    4104
# Name: worldwide_gross, dtype: int64

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = np.nan, strategy = 'mean', axis=1)

# %%
movies_V3=movies_V3.drop('movie_title',axis=1)

# %%
movies_V3=movies_V3.drop('duration',axis=1)

# %%
movies_V3
# Out:
#       title_year  aspect_ratio  duration.1       budget  imdb_score  \
# 0         2009.0          1.78       178.0  237000000.0         7.9
# 1         2007.0          2.35       169.0  300000000.0         7.1
# 2         2015.0          2.35       148.0  245000000.0         6.8
# 3         2012.0          2.35       164.0  250000000.0         8.5
# 4            NaN           NaN         NaN          NaN         7.1
# 5         2012.0          2.35       132.0  263700000.0         6.6
# 6         2007.0          2.35       156.0  258000000.0         6.2
# 7         2007.0          2.35       156.0  258000000.0         6.2
# 8         2010.0          1.85       100.0  260000000.0         7.8
# 9         2015.0          2.35       141.0  250000000.0         7.5
# 10        2009.0          2.35       153.0  250000000.0         7.5
# 11        2016.0          2.35       183.0  250000000.0         6.9
# 12        2006.0          2.35       169.0  209000000.0         6.1
# 13        2008.0          2.35       106.0  200000000.0         6.7
# 14        2006.0          2.35       151.0  225000000.0         7.3
# 15        2013.0          2.35       150.0  215000000.0         6.5
# 16        2013.0          2.35       143.0  225000000.0         7.2
# 17        2008.0          2.35       150.0  225000000.0         6.6
# 18        2011.0          2.35       136.0  250000000.0         6.7
# 19        2014.0          2.35       164.0  250000000.0         7.5
# 20        2012.0          2.35       153.0  230000000.0         7.0
# 21        2010.0          2.35       156.0  200000000.0         6.7
# 22        2013.0          2.35       186.0  225000000.0         7.9
# 23        1997.0          2.35       194.0  200000000.0         7.7
# 24        2016.0          2.35       147.0  250000000.0         8.2
# 25        2012.0          2.35       131.0  209000000.0         5.9
# 26        2015.0          2.00       124.0  150000000.0         7.0
# 27        2012.0          2.35       143.0  200000000.0         7.8
# 28        2012.0          2.35       143.0  200000000.0         7.8
# 29        2004.0          2.35       135.0  200000000.0         7.3
# ...          ...           ...         ...          ...         ...
# 4338      2015.0          1.78       111.0      50000.0         6.0
# 4341      2014.0          2.35        97.0    4000000.0         6.1
# 4345      2000.0          2.35        90.0      42000.0         7.5
# 4346      1999.0          1.85        90.0      40000.0         7.6
# 4347      2014.0           NaN        95.0      75000.0         5.0
# 4348      2011.0          2.35        83.0      40000.0         3.2
# 4349      1978.0          1.85       117.0          NaN         8.2
# 4351      2009.0           NaN        79.0          NaN         6.3
# 4352      2007.0          2.35        78.0      30000.0         4.1
# 4353      2005.0          1.66       109.0          NaN         6.9
# 4355      2009.0           NaN        93.0          NaN         6.5
# 4356      1994.0          1.37       102.0     230000.0         7.8
# 4357      1971.0          1.37        65.0      27000.0         6.7
# 4358      2002.0          1.37        85.0          NaN         6.4
# 4359      1997.0          1.85        97.0      25000.0         7.3
# 4361      1991.0          1.37       100.0      23000.0         7.1
# 4366      2005.0           NaN        85.0      15000.0         6.6
# 4368      2009.0          2.35        88.0      15000.0         6.2
# 4370      1972.0          1.37       108.0      10000.0         6.1
# 4371      2004.0          2.35       110.0       4500.0         6.9
# 4372      1997.0          1.85       111.0    1000000.0         7.4
# 4373      2004.0           NaN        84.0          NaN         6.1
# 4375      1995.0           NaN        98.0          NaN         6.4
# 4376      2004.0          1.85        77.0       7000.0         7.0
# 4377      2005.0           NaN        80.0       7000.0         6.3
# 4378      1992.0          1.37        81.0       7000.0         6.9
# 4379      2005.0           NaN        84.0       3250.0         7.8
# 4380      2011.0           NaN        95.0       9000.0         6.4
# 4383      2012.0          2.35       100.0          NaN         6.3
# 4384      2004.0          1.85        90.0       1100.0         6.6
#
#             gross  cast_total_facebook_likes  worldwide_gross
# 0     760505847.0                       4834       2783918982
# 1     309404152.0                      48350        963420425
# 2     200074175.0                      11700        879620923
# 3     448130642.0                     106759       1084439099
# 4             NaN                        143       2058662225
# 5      73058679.0                       1873        282778100
# 6     336530303.0                      46055        890875303
# 7     336530303.0                      46055        890875303
# 8     200807262.0                       2036        586581936
# 9     458991599.0                      92000       1404705868
# 10    301956980.0                      58753        935083686
# 11    330249062.0                      24450        868160194
# 12    200069408.0                      29991        374085065
# 13    168368427.0                       2023        591692078
# 14    423032628.0                      48486       1066215812
# 15     89289910.0                      45757        260002115
# 16    291021565.0                      20495        667999518
# 17    141614023.0                      22697        417341288
# 18    241063875.0                      54083       1045663875
# 19    255108370.0                       9152        955119788
# 20    262030663.0                      28489        757890267
# 21    105219735.0                       3244        322241588
# 22    258355354.0                       9152        960366855
# 23    658672302.0                      45223       2207615668
# 24    407197282.0                      64798       1150864745
# 25     65173160.0                      26679        305218228
# 26    652177271.0                       8458       1670328025
# 27    304360277.0                       2039       1110526981
# 28    304360277.0                       2039       1110526981
# 29    373377893.0                      43388        783705001
# ...           ...                        ...              ...
# 4338          NaN                          0             8374
# 4341          NaN                       1922           406299
# 4345     241816.0                        642           342722
# 4346     277233.0                      20814           277233
# 4347          NaN                       2618             8799
# 4348          NaN                        619             3632
# 4349     321952.0                       2783           321952
# 4351      24705.0                       1054            25572
# 4352     243768.0                         72           243768
# 4353          NaN                         38           103509
# 4355       9609.0                        365             9812
# 4356    3151130.0                       2103          3894240
# 4357       8231.0                          0             8231
# 4358          NaN                         40            82698
# 4359    2856622.0                        254          2883661
# 4361    1227508.0                          5          1227508
# 4366     192467.0                       1064           195254
# 4368      76382.0                       1546           115592
# 4370     180483.0                        760           413802
# 4371     136007.0                        776           138711
# 4372      94596.0                        115          1239174
# 4373          NaN                         62             1987
# 4375          NaN                       1186              527
# 4376     424760.0                        368           841926
# 4377      70071.0                          0            71644
# 4378    2040920.0                        147          2041928
# 4379          NaN                         93              900
# 4380       4584.0                        690             4584
# 4383      10443.0                       2386            10443
# 4384      85222.0                        163           181041
#
# [4104 rows x 8 columns]

# %%
values = imputer.fit_transform(movies_V3)

# %%
values
# Out:
# array([[2.00900000e+03, 1.78000000e+00, 1.78000000e+02, ...,
#         7.60505847e+08, 4.83400000e+03, 2.78391898e+09],
#        [2.00700000e+03, 2.35000000e+00, 1.69000000e+02, ...,
#         3.09404152e+08, 4.83500000e+04, 9.63420425e+08],
#        [2.01500000e+03, 2.35000000e+00, 1.48000000e+02, ...,
#         2.00074175e+08, 1.17000000e+04, 8.79620923e+08],
#        ...,
#        [2.01100000e+03, 2.99577143e+03, 9.50000000e+01, ...,
#         4.58400000e+03, 6.90000000e+02, 4.58400000e+03],
#        [2.01200000e+03, 2.35000000e+00, 1.00000000e+02, ...,
#         1.04430000e+04, 2.38600000e+03, 1.04430000e+04],
#        [2.00400000e+03, 1.85000000e+00, 9.00000000e+01, ...,
#         8.52220000e+04, 1.63000000e+02, 1.81041000e+05]])

# %%
x = pd.DataFrame(values)

# %%
x.columns = movies_V3.columns

# %%
x.index= movies_V3.index

# %%
x.head()
# Out:
#     title_year  aspect_ratio   duration.1       budget  imdb_score  \
# 0       2009.0  1.780000e+00        178.0  237000000.0         7.9
# 1       2007.0  2.350000e+00        169.0  300000000.0         7.1
# 2       2015.0  2.350000e+00        148.0  245000000.0         6.8
# 3       2012.0  2.350000e+00        164.0  250000000.0         8.5
# 4  686220791.7  6.862208e+08  686220791.7  686220791.7         7.1
#
#          gross  cast_total_facebook_likes  worldwide_gross
# 0  760505847.0                     4834.0     2.783919e+09
# 1  309404152.0                    48350.0     9.634204e+08
# 2  200074175.0                    11700.0     8.796209e+08
# 3  448130642.0                   106759.0     1.084439e+09
# 4  686220791.7                      143.0     2.058662e+09

# %%
x.to_csv('x.csv',index=False)
