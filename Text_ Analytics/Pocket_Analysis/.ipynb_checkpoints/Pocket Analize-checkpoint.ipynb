# %% [markdown]
# # Analysis Habit reading  with [Pocket](https://getpocket.com/)

# %% [markdown]
# ![](unnamed.jpg)

# %% [markdown]
# How I'm in the top 1% of readers on @Pocket for 2018! I have decided to analyze my pocket data to try to understand my reading habits.
#
# In this Jupyter Notebook, we are going to cover all ETL process and the data analysis process in a low level of complexity and low data volume, although in some cases, we are going to call analysis methods the middle level like language detect or text analysis.
#
# But before we start writing code, we should ask ourselves, what are we looking for? Or what do we want to find in the analysis? The best way to do this is to ask preliminary questions about the data we want to answer, such as
#
# - How many articles I’ve added to my Pocket till date?
# - How many articles have I read / I need to read?
# - How large is the gap between added and read articles?
# - What topics do I add articles about?
#
# To try answer this question, we will follow the next steps.
#
# 0. Import Libraries
# 1. ***Extract***.Set and get data from the pocket API with [Request]()<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.1.Get a consumer_key <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.2.Get a request token <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.3.Authenticate<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.4.Generate an access_token <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.5.Get Data <br/>
# 2. ***Transform and Load*** data with [Pandas]() <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.1.Detect the type of python object from the obtained <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.2.Transform the data to a useful Pandas Dataframe <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.3.Pre-analyze the columns of your data frame <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.4.Debug your data frame <br/>
# 3. ***Data Analysis*** with [Pandas]() <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.1.Numerical Analysis <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.2.Text analysis with []() <br/>
# 4. ***Data Vizualization*** with  [Power BI]() <br/>
#
#
# finally, before starting with the notebook it's important to note that although the complexity level is low all the principles of data analysis are practice ins this exercise. , this means that with this knowledge you can try to analyze more complex  scenarios

# %% [markdown]
# ***0.*** Import necessary libraries

# %%
import requests # to make http requests in this case for pocket api

# data transfromation and analysis
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import json 
from collections import OrderedDict
import datetime
import pyodbc # Library to manage odbc connection in this case we work with SQl SERVER
import sqlalchemy as sa

# text analysis
from wordcloud import WordCloud, STOPWORDS 
import detectlanguage #Api

#Data visualizacion and plot
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ##  1. Extract. Set and get dat from the pocket API
#
# ***1.1*** Get a consumer_key by creating a new [Pocket application](https://getpocket.com/developer/apps/new) <br/>
# ***1.2*** Get a request token<br/>

# %%
# pocket_api variable stores the http response
pocket_api = requests.post('https://getpocket.com/v3/oauth/request',
                           data = {'consumer_key':'82710-efa2906be95b400ce9fad6f8',
                                   'redirect_uri':'https://google.com'})

#Test Status If equal to 200 is ok the other way check error reason
print(pocket_api.status_code) 

# print(pocket_api.headers['X-Error'])

# Here is your request_token stored
print(pocket_api.text)
# Out:
# 200
# code=a9b9694e-c46e-9b7e-4c66-95848b

# %% [markdown]
# ***1.3*** Authenticate<br/>
# - Modify and paste the link below in the browser and authenticate <br/>
# - Replace text after "?request_token=" with the request_token generated above<br/>
# https://getpocket.com/auth/authorize?request_token=PASTE-YOUR-REQUEST-TOKEN-HERE&amp;amp;amp;amp;amp;amp;amp;amp;amp;redirect_uri=https://getpocket.com/connected_application

# %% [markdown]
#  **1.4** Generate an access_token
# - After authenticating in the browser, return here
# - Use your consumer_key and request_token below

# %%
pocket_auth = requests.post('https://getpocket.com/v3/oauth/authorize',
                            data = {'consumer_key':'82710-efa2906be95b400ce9fad6f8',
                                    'code':'51947cf3-8998-32b6-e129-26e865'})
# Check the response: if 200, then it means all OK
pocket_auth.status_code
 
# Check error reason, if any
# print(pocket_auth.headers['X-Error'])
# We're done authenticating,this is your access token
pocket_auth.text
# Out:
# '403 Forbidden'

# %% [markdown]
# ***1.5.*** Get Data from the api

# %%
# Get data from the API
# Reference: https://getpocket.com/developer/docs/v3/retrieve
pocket_add = requests.post('https://getpocket.com/v3/get',
                           data= {'consumer_key':'82710-efa2906be95b400ce9fad6f8',
                                  'access_token':'81159e5f-c60a-dadd-0b50-1b1c40',#private
                                  'state':'all',
                                  'detailType':'simple'})
 
# Check the response: if 200, then it means all OK
# pocket_add.status_code
 
#pocket_add.text

# %% [markdown]
# ## 2.Transform data

# %% [markdown]
# ***2.1.*** Detect the type of python object from the obtained

# %%
print(type(pocket_add))
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# ***2.2.*** Transform from respuest reponse object to pd.df

# %%
texto=pocket_add.text
json_data = json.loads(texto)
df= pd.DataFrame.from_dict(json_data['list']).T
df.head()
# Out:
#            amp_url                                    domain_metadata  \
# 2442351725     NaN                                                NaN
# 2442848392     NaN  {'name': 'Towards Data Science', 'logo': 'http...
# 2068946        NaN  {'name': 'Wikipedia', 'logo': 'https://logo.cl...
# 2382135264     NaN  {'name': 'Hacker Noon', 'logo': 'https://logo....
# 1702096649     NaN                                                NaN
#
#                                                       excerpt favorite  \
# 2442351725  There are times when working with different pa...        0
# 2442848392  Logistic Regression is one of the basic and po...        0
# 2068946     In statistics, logistic regression, or logit r...        0
# 2382135264  So, you’re playing with ML models and you enco...        0
# 1702096649                                                           0
#
#                                                   given_title  \
# 2442351725  Python Data: Quick Tip: Comparing two pandas d...
# 2442848392                                          302 Found
# 2068946                       Logistic regression - Wikipedia
# 2382135264                                          302 Found
# 1702096649                                      glorot10a.pdf
#
#                                                     given_url has_image  \
# 2442351725  https://pythondata.com/quick-tip-comparing-two...         0
# 2442848392  https://towardsdatascience.com/understanding-l...         1
# 2068946     https://en.wikipedia.org/wiki/Logistic_regression         1
# 2382135264  https://hackernoon.com/what-is-one-hot-encodin...         1
# 1702096649  http://proceedings.mlr.press/v9/glorot10a/glor...         0
#
#            has_video is_article is_index    ...      \
# 2442351725         0          1        0    ...
# 2442848392         0          1        0    ...
# 2068946            0          1        0    ...
# 2382135264         1          1        0    ...
# 1702096649         0          0        0    ...
#
#                                                  resolved_url sort_id status  \
# 2442351725  https://pythondata.com/quick-tip-comparing-two...       0      0
# 2442848392  https://towardsdatascience.com/understanding-l...       1      0
# 2068946     https://en.wikipedia.org/wiki/Logistic_regression       2      0
# 2382135264  https://hackernoon.com/what-is-one-hot-encodin...       3      0
# 1702096649  http://proceedings.mlr.press/v9/glorot10a/glor...       4      0
#
#             time_added time_favorited time_read time_to_read time_updated  \
# 2442351725  1546608445              0         0          NaN   1546608447
# 2442848392  1546606419              0         0            3   1546606420
# 2068946     1546606066              0         0           55   1546606066
# 2382135264  1546604896              0         0          NaN   1546604896
# 1702096649  1546553387              0         0          NaN   1546553387
#
#                                                 top_image_url word_count
# 2442351725  https://ir-na.amazon-adsystem.com/e/ir?t=edbho...        232
# 2442848392  https://cdn-images-1.medium.com/max/1200/1*715...        640
# 2068946     https://upload.wikimedia.org/wikipedia/commons...      12010
# 2382135264  https://cdn-images-1.medium.com/max/1200/1*VEU...        386
# 1702096649                                                NaN          0
#
# [5 rows x 25 columns]

# %% [markdown]
# ***2.3.*** Pre-analyze the columns of your data frame

# %%
df.notnull().apply(pd.Series.value_counts)
# Out:
#        amp_url  domain_metadata  excerpt  favorite  given_title  given_url  \
# False     2243             1813        4       NaN          NaN        NaN
# True       328              758     2567    2571.0       2571.0     2571.0
#
#        has_image  has_video  is_article  is_index     ...      resolved_url  \
# False          4          4           4         4     ...                 4
# True        2567       2567        2567      2567     ...              2567
#
#        sort_id  status  time_added  time_favorited  time_read  time_to_read  \
# False      NaN     NaN         NaN             NaN        NaN          1250
# True    2571.0  2571.0      2571.0          2571.0     2571.0          1321
#
#        time_updated  top_image_url  word_count
# False           NaN           1192           4
# True         2571.0           1379        2567
#
# [2 rows x 25 columns]

# %%
df.dtypes
# Out:
# amp_url                     object
# domain_metadata             object
# excerpt                     object
# favorite                    object
# given_title                 object
# given_url                   object
# has_image                   object
# has_video                   object
# is_article                  object
# is_index                    object
# item_id                     object
# lang                        object
# listen_duration_estimate    object
# resolved_id                 object
# resolved_title              object
# resolved_url                object
# sort_id                     object
# status                      object
# time_added                  object
# time_favorited              object
# time_read                   object
# time_to_read                object
# time_updated                object
# top_image_url               object
# word_count                  object
# dtype: object

# %% [markdown]
# ***2.4.*** Debug your data frame

# %%
# Clean up the dataset
available = df.notnull()
mask= available['word_count']&available['time_to_read']
df = df[mask]

# %%
df.dtypes
df[['status','favorite','word_count','time_to_read']] = df[['status','favorite','word_count','time_to_read']].astype(int)
df['time_added'] = pd.to_datetime(df['time_added'],unit='s')
df['time_read'] = pd.to_datetime(df['time_read'],unit='s')

df['date_added'] = df['time_added'].dt.date
df['date_read'] = df['time_read'].dt.date

# Check the data types
df.dtypes
# Out:
# amp_url                             object
# domain_metadata                     object
# excerpt                             object
# favorite                             int32
# given_title                         object
# given_url                           object
# has_image                           object
# has_video                           object
# is_article                          object
# is_index                            object
# item_id                             object
# lang                                object
# listen_duration_estimate            object
# resolved_id                         object
# resolved_title                      object
# resolved_url                        object
# sort_id                             object
# status                               int32
# time_added                  datetime64[ns]
# time_favorited                      object
# time_read                   datetime64[ns]
# time_to_read                         int32
# time_updated                        object
# top_image_url                       object
# word_count                           int32
# date_added                          object
# date_read                           object
# dtype: object

# %% [markdown]
# # 3. Data Analysis
# ### 3.1. Answer questions using data

# %%
df.head()
# Out:
#            amp_url                                    domain_metadata  \
# 2442848392     NaN  {'name': 'Towards Data Science', 'logo': 'http...
# 2068946        NaN  {'name': 'Wikipedia', 'logo': 'https://logo.cl...
# 909334469      NaN                                                NaN
# 2435595681     NaN  {'name': 'Towards Data Science', 'logo': 'http...
# 2435726794     NaN                                                NaN
#
#                                                       excerpt  favorite  \
# 2442848392  Logistic Regression is one of the basic and po...         0
# 2068946     In statistics, logistic regression, or logit r...         0
# 909334469   The result of a JOIN does not depends on the p...         0
# 2435595681  Recommender systems are one of the most common...         0
# 2435726794  As a marketing manager, you want a set of cust...         0
#
#                                         given_title  \
# 2442848392                                302 Found
# 2068946             Logistic regression - Wikipedia
# 909334469   From SQL to DAX: Joining Tables - SQLBI
# 2435595681                                302 Found
# 2435726794   Decision Tree Classification in Python
#
#                                                     given_url has_image  \
# 2442848392  https://towardsdatascience.com/understanding-l...         1
# 2068946     https://en.wikipedia.org/wiki/Logistic_regression         1
# 909334469   https://www.sqlbi.com/articles/from-sql-to-dax...         1
# 2435595681  https://towardsdatascience.com/building-and-te...         1
# 2435726794  https://www.datacamp.com/community/tutorials/d...         1
#
#            has_video is_article is_index     ...     status  \
# 2442848392         0          1        0     ...          0
# 2068946            0          1        0     ...          0
# 909334469          0          1        0     ...          0
# 2435595681         1          1        0     ...          0
# 2435726794         0          1        0     ...          0
#
#                     time_added time_favorited  time_read time_to_read  \
# 2442848392 2019-01-04 12:53:39              0 1970-01-01            3
# 2068946    2019-01-04 12:47:46              0 1970-01-01           55
# 909334469  2019-01-03 14:37:28              0 1970-01-01            8
# 2435595681 2019-01-02 13:08:20              0 1970-01-01            5
# 2435726794 2019-01-02 12:51:08              0 1970-01-01            9
#
#            time_updated                                      top_image_url  \
# 2442848392   1546606420  https://cdn-images-1.medium.com/max/1200/1*715...
# 2068946      1546606066  https://upload.wikimedia.org/wikipedia/commons...
# 909334469    1546526248  https://www.sqlbi.com/wp-content/uploads/Natur...
# 2435595681   1546434500  https://cdn-images-1.medium.com/max/1200/1*dOM...
# 2435726794   1546433469  https://s3.amazonaws.com/datacamp-community-pr...
#
#             word_count  date_added   date_read
# 2442848392         640  2019-01-04  1970-01-01
# 2068946          12010  2019-01-04  1970-01-01
# 909334469         1660  2019-01-03  1970-01-01
# 2435595681        1055  2019-01-02  1970-01-01
# 2435726794        2076  2019-01-02  1970-01-01
#
# [5 rows x 27 columns]

# %%
 
# How many items are there in my Pocket?
print('How many items are there in my Pocket? R\{}'.format(df['item_id'].count()))
 
# What % of articles are read?
print('What % of articles are read? R\{}'.format((df['status'].sum()*100)/df['item_id'].count()))
# Out:
# How many items are there in my Pocket? R\1321
# What % of articles are read? R\98.03179409538228

# %%
# How long is the average article in my Pocket? (minutes)
df['time_to_read'].describe()
# Out:
# count    1321.000000
# mean        8.099924
# std         9.107889
# min         3.000000
# 25%         4.000000
# 50%         6.000000
# 75%         9.000000
# max       155.000000
# Name: time_to_read, dtype: float64

# %%
# How long is the average article in my Pocket? (word count)
df['word_count'].describe()
# Out:
# count     1321.000000
# mean      1775.887207
# std       2004.766245
# min        550.000000
# 25%        842.000000
# 50%       1250.000000
# 75%       2057.000000
# max      34197.000000
# Name: word_count, dtype: float64

# %%
# How many words have I read till date?
print('How many words have I read till date? R/{}'.format(df.loc[df['status'] == 1, 'word_count'].sum()))
 
# How many books is this equivalent to?
print('How many books is this equivalent to? R/{}'.format(df.loc[df['status'] == 1, 'word_count'].sum()/64000))
# Out:
# How many words have I read till date? R/2286730
# How many books is this equivalent to? R/35.73015625

# %%
# How were the articles added over time?
plot_added = df.groupby('date_added')['item_id'].count()
plot_added.plot()

# %%
# How were the articles read over time?
plot_read = df.groupby('date_read')['status'].sum()
plot_read.plot()

# %% [markdown]
# As the achievement of belonging to 1% of readers in pocket is based on data 2018 it is necessary to filter the data to analyze only this information.

# %%
# filter Time
start_date ='01-01-2018'
end_date = '31-12-2018'
mask_2 = (df['time_read'] > start_date) & (df['time_read'] <= end_date)
df_2018= df[mask_2]
# How many words have I read till date?
print('How many words have I read in 2018? R/{}'.format(df_2018.loc[df['status'] == 1, 'word_count'].sum()))                                                                     
# How many books is this equivalent to?
print('How many books is this equivalent to? R/{}'.format(df_2018.loc[df['status'] == 1, 'word_count'].sum()/64000))
# Out:
# How many words have I read in 2018? R/1465004
# How many books is this equivalent to? R/22.8906875

# %% [markdown]
# # Text Analysis

# %% [markdown]
# Part of the analysis I'm going to do is supported by an API that detects the language, because developing and training the algorithm necessary to detect the language is out of reach and would greatly extend the article
#
# We have to do some transformation more to can use teh API

# %%
#prepare data to text analysis again tranformation reindexing
df_2018 = df_2018.reset_index()
texto = df_2018['excerpt'].tolist()

# %%
detectlanguage.configuration.api_key = "3a6545f3c5a180ff549ddf334d2ec8ec"
detectlanguage.user_status()
# Out:
# {'date': '2019-01-07',
#  'requests': 0,
#  'bytes': 0,
#  'plan': 'FREE',
#  'plan_expires': None,
#  'daily_requests_limit': 1000,
#  'daily_bytes_limit': 1048576,
#  'status': 'ACTIVE'}

# %%
language_analysis = detectlanguage.detect(texto)
type(language_analysis)
# Out:
# list

# %%
language_analysis
# Out:
# [[{'language': 'en', 'isReliable': True, 'confidence': 10.7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.44}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.42}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.62}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.99}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.3}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.91}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.57}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.3}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.87}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.61}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.99}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.71}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.74}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.44}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.48}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.87}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.41}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.41}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 2.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.76}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.74}],
#  [{'language': 'es', 'isReliable': False, 'confidence': 5.5}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.7}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.46}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.49}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.48}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.78}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.67}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.41}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.56}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.81}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.25}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.32}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.41}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.44}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.87}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.86}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.25}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 6.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.33}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.49}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.94}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.9}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.79}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.49}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.1}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.02}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.79}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.87}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.56}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.09}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.97}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.97}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.87}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.89}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.67}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.27}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.74}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.09}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.94}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.57}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 16.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.48}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.63}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.73}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.73}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.38}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.38}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.94}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.05}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.34}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.86}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.32}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.34}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.59}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.97}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.71}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.03}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.28}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.81}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.59}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.88}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.04}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.42}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.05}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.69}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.16}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 2.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.77}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.81}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.89}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.34}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.39}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.66}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.05}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.87}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.73}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.62}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.25}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.94}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.25}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.93}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.1}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.74}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.54}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.41}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.79}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.65}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.67}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.69}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.34}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.8}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.49}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.91}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.31}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.3}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.4}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.22}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.3}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.16}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.26}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.42}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.25}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.28}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.74}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.55}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.42}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.51}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.37}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.05}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.39}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.47}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.49}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.32}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.57}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.81}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.99}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.99}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.05},
#   {'language': 'en', 'isReliable': False, 'confidence': 5.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.34}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.66}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.79}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.57}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.56}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.57}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.38}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.94}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.09}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.44}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.87}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.87}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.14}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.59}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.66}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.9}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 16.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.93}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.25}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.89}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.62}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 4.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.76}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.67}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.93}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.06}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.62}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.02}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.69}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.81}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.76}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.16}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.63}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.28}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.25}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.46}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.57}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.61}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.9}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.39}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.82}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.86}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.44}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.34}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.95}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.96}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 8.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.3}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.43}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.07}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.74}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.48}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.88}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.25}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.02}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.53}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.1}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.74}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.78}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.67}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.39}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.85}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.86}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.65}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.84}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.69}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.29}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.79}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.7}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.31}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.46}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.5}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.28}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.91}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.7}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.08}],
#  [{'language': 'gl', 'isReliable': True, 'confidence': 5.89}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.89}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.92}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.42}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.19}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.23}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.39}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.39}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.77}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.03}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.69}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.1}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.56}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.01}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.16}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.41}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.86}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.89}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.51}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.1}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.36}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.13}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.36}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.76}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.37}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 2.21}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.2},
#   {'language': 'en', 'isReliable': False, 'confidence': 10.59}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.88}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.63}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.21}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 16.44}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.48}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.38}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.28}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.63}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.4}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.3}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.39}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.47}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 2.98},
#   {'language': 'en', 'isReliable': False, 'confidence': 10.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.75}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.21}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.5}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.14}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.97}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.74}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 9.75}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.53}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.08}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.41}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.77}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.97}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.86}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.69}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.72}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.12}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.73}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.1}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.1}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.97}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 6.31}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.89}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.79}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.11}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.71}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.15}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.83}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.07}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 15.55}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.09}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.71}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 9.68}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 7.47}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.79}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.93}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.7}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.29}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.11}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.27}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.53}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.44}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.18}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.14}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.6}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.08}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.2}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.8}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.69},
#   {'language': 'en', 'isReliable': False, 'confidence': 10.6}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.36}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.32}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.71}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.81}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.98}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.55}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.15}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.85}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.58}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.94}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.46}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.54}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.32}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.98}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 14.85}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.8}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.53}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.4}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.93}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.35}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 11.93}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.52}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 12.45}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.31}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.49}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.85}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.24}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.78}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.92}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.9}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.14}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.72}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.51}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.42}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.78}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.67}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.25}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.29}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.28}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.28}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.51}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 11.72}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.25}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 11.12}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.87}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.71}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.8}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 7.43}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.45}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 2.38},
#   {'language': 'en', 'isReliable': False, 'confidence': 10.24}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.91}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.17}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.39}],
#  [{'language': 'es', 'isReliable': False, 'confidence': 4.04}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 13.9}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.74}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.6}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 5.49}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 4.94}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 6.52}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 8.29}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.64}],
#  [{'language': 'en', 'isReliable': True, 'confidence': 10.2}],
#  [{'language': 'es', 'isReliable': True, 'confidence': 3.06}]]

# %%
# get the language field from the list return and add to the dataframe 

lista = []

for listItem in language_analysis:
    for item in listItem :
        lista.append(item.get('language'))
           
            
language_column= pd.Series(lista)           

df_2018['Language']= language_column

df_2018.to_csv("pocket_2018.csv")

# %%
df_2018.head()
# Out:
#         index                                            amp_url  \
# 0  1974827225                                                NaN
# 1  2137887466                                                NaN
# 2   247320106                                                NaN
# 3  1408395881  https://www.technologyreview.com/s/602344/the-...
# 4  2426258218                                                NaN
#
#                                      domain_metadata  \
# 0  {'name': 'Towards Data Science', 'logo': 'http...
# 1                                                NaN
# 2  {'name': 'Pocket', 'logo': 'https://logo.clear...
# 3  {'name': 'MIT Technology Review', 'logo': 'htt...
# 4                                                NaN
#
#                                              excerpt  favorite  \
# 0  A few weeks ago, a colleague sent me a spreads...         1
# 1  I joined Facebook in May 2007. Over the past 1...         1
# 2  The Pocket Authentication API uses a variant o...         0
# 3  In the last couple of years, deep learning tec...         0
# 4  Instagram machine learning has grown a lot sin...         0
#
#                                          given_title  \
# 0  Seven Clean Steps To Reshape Your Data With Pa...
# 1  Analyzing 10  Years of My Facebook Data - Lee ...
# 2  Pocket Developer Program: Pocket Authenticatio...
# 3  The Extraordinary Link Between Deep Neural Net...
# 4                                          302 Found
#
#                                            given_url has_image has_video  \
# 0  https://towardsdatascience.com/seven-clean-ste...         1         0
# 1  https://www.leejamesrobinson.com/blog/analyzin...         1         0
# 2  https://getpocket.com/developer/docs/authentic...         0         0
# 3  https://www.technologyreview.com/s/602344/the-...         1         0
# 4  https://instagram-engineering.com/lessons-lear...         1         0
#
#   is_article   ...             time_added time_favorited           time_read  \
# 0          1   ...    2018-12-20 15:06:41     1546195622 2018-12-30 18:47:05
# 1          1   ...    2018-12-20 13:22:49     1546195359 2018-12-30 18:42:40
# 2          1   ...    2018-12-19 19:33:46              0 2018-12-21 13:30:47
# 3          1   ...    2018-12-19 12:33:20              0 2018-12-30 19:06:26
# 4          1   ...    2018-12-19 11:46:21              0 2018-12-30 18:40:23
#
#   time_to_read time_updated  \
# 0           10   1546195706
# 1            4   1546433123
# 2            9   1545399047
# 3            5   1546196792
# 4            7   1546195394
#
#                                        top_image_url word_count  date_added  \
# 0  https://cdn-images-1.medium.com/max/1200/1*jxg...       2114  2018-12-20
# 1  http://www.leejamesrobinson.com/img/facebook/b...        934  2018-12-20
# 2                                                NaN       2029  2018-12-19
# 3  https://cdn.technologyreview.com/i/images/deep...       1074  2018-12-19
# 4  https://cdn-images-1.medium.com/max/1200/1*gkK...       1617  2018-12-19
#
#     date_read Language
# 0  2018-12-30       en
# 1  2018-12-30       en
# 2  2018-12-21       en
# 3  2018-12-30       en
# 4  2018-12-30       en
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Load Data ( Optional Step just to production)

# %%
import urllib
params = urllib.parse.quote_plus(r"Driver={SQL Server};Server=localhost;Database=Projects;Trusted_Connection=Yes")
engine = sa.create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))
df_2018.to_sql('Pocket_Data', con=engine, index=False,  if_exists='append')
# Out:
# Database created

# %%
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     505     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 506         cursor.executemany(statement, parameters)
#     507
#
# ProgrammingError: ('Invalid parameter type.  param-index=1 param-type=dict', 'HY105')
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-67-cd4dcad2546e> in <module>()
#       3 params = urllib.parse.quote_plus(r"Driver={SQL Server};Server=bielondono;Database=Projects;Trusted_Connection=Yes")
#       4 engine = sa.create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))
# ----> 5 df_2018.to_sql('Pocket_Data', con=engine, index=False,  if_exists='append')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     504
#     505     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 506         cursor.executemany(statement, parameters)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
#
# ProgrammingError: (pyodbc.ProgrammingError) ('Invalid parameter type.  param-index=1 param-type=dict', 'HY105') [SQL: 'INSERT INTO [Pocket_Data] (amp_url, domain_metadata, excerpt, favorite, given_title, given_url, has_image, has_video, is_article, is_index, item_id, lang, listen_duration_estimate, resolved_id, resolved_title, resolved_url, sort_id, status, time_added, time_favorited, time_read, time_to_read, time_updated, top_image_url, word_count, date_added, date_read, [Language]) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)'] [parameters: ((None, {'name': 'Towards Data Science', 'logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800', 'greyscale_logo': 'https://logo.clearbit.com/towardsdatascience.com?size=800&greyscale=true'}, 'A few weeks ago, a colleague sent me a spreadsheet with data on a public health intervention, consisting of many tabs, one tab per organization. The task was to develop a flexible dashboard to explore this data. The problem was that the data was in wide format, but we needed a long format.', 1, 'Seven Clean Steps To Reshape Your Data With Pandas Or How I Use Python Wher', 'https://towardsdatascience.com/seven-clean-steps-to-reshape-your-data-with-pandas-or-how-i-use-python-where-excel-fails-62061f86ef9c', '1', '0', '1', '0', '1974827225', 'en', 818, '1974827225', 'Seven Clean Steps To Reshape Your Data With Pandas Or How I Use Python Where Excel\xa0Fails', 'https://towardsdatascience.com/seven-clean-steps-to-reshape-your-data-with-pandas-or-how-i-use-python-where-excel-fails-62061f86ef9c', 51, 1, datetime.datetime(2018, 12, 20, 15, 6, 41), '1546195622', datetime.datetime(2018, 12, 30, 18, 47, 5), 10, '1546195706', 'https://cdn-images-1.medium.com/max/1200/1*jxgWJFpveSKM9YzgQDNzFw.png', 2114, datetime.datetime(2018, 12, 20, 0, 0), datetime.datetime(2018, 12, 30, 0, 0), 'en'), (None, None, 'I joined Facebook in May 2007. Over the past 10+ years, my activity has ranged from being heavily involved to barely using it for over a year. In the wake of the #DeleteFacebook uproar, I started to think about my social media footprint.', 1, 'Analyzing 10  Years of My Facebook Data - Lee Robinson', 'https://www.leejamesrobinson.com/blog/analyzing-10-years-of-facebook-data/', '1', '0', '1', '0', '2137887466', 'en', 362, '2137887466', 'Analyzing 10+ Years of My Facebook Data', 'https://www.leejamesrobinson.com/blog/analyzing-10-years-of-facebook-data/', 52, 1, datetime.datetime(2018, 12, 20, 13, 22, 49), '1546195359', datetime.datetime(2018, 12, 30, 18, 42, 40), 4, '1546433123', 'http://www.leejamesrobinson.com/img/facebook/banner.png', 934, datetime.datetime(2018, 12, 20, 0, 0), datetime.datetime(2018, 12, 30, 0, 0), 'en'), (None, {'name': 'Pocket', 'logo': 'https://logo.clearbit.com/getpocket.com?size=800', 'greyscale_logo': 'https://logo.clearbit.com/getpocket.com?size=800&greyscale=true'}, 'The Pocket Authentication API uses a variant of OAuth 2.0 for authentication. OAuth 2.', 0, 'Pocket Developer Program: Pocket Authentication API: Documentation', 'https://getpocket.com/developer/docs/authentication', '0', '0', '1', '1', '247320106', 'en', 785, '247320106', 'Pocket Authentication API Documentation', 'https://getpocket.com/developer/docs/authentication', 55, 1, datetime.datetime(2018, 12, 19, 19, 33, 46), '0', datetime.datetime(2018, 12, 21, 13, 30, 47), 9, '1545399047', None, 2029, datetime.datetime(2018, 12, 19, 0, 0), datetime.datetime(2018, 12, 21, 0, 0), 'en'), ('https://www.technologyreview.com/s/602344/the-extraordinary-link-between-deep-neural-networks-and-the-nature-of-the-universe/amp/', {'name': 'MIT Technology Review', 'logo': 'https://logo.clearbit.com/technologyreview.com?size=800', 'greyscale_logo': 'https://logo.clearbit.com/technologyreview.com?size=800&greyscale=true'}, 'In the last couple of years, deep learning techniques have transformed the world of artificial intelligence. One by one, the abilities and techniques that humans once ...

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color='white',
                      stopwords=stopwords,
                      max_words=300,
                      max_font_size=40, 
                      random_state=42
                      ).generate(str(df_2018['given_title']))
 
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("Pocket Wordcloud.png", dpi=900)

# %%
from IPython.display import IFrame

powerBiEmbed = 'https://app.powerbi.com/view?r=[...]'

IFrame(powerBiEmbed, width=800, height=600)
